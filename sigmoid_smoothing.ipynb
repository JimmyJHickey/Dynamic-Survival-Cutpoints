# %% [markdown]
# # Generate simulated data

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import exp

from scipy.optimize import minimize
import scipy.stats

# %%
# shifted and scaled sigmoid function
def sigmoid(x, a=0, b=1.):
    return 1 / (1 + (np.exp(-1 * (x - a) / b)))

# %%
N = 10000
P = 5

rs = np.random.RandomState(1978)

X = rs.randn(N, P)
w = rs.randn(P)

y_prob = sigmoid(X @ w)
y = (rs.rand(N) < y_prob).astype(int)

# %%
plt.hist(y_prob)
plt.show()

# %%
t = (rs.randn(N) + 5 * y) / 20 + .1

# %%
plt.hist(t, bins=50)
plt.show()

# %% [markdown]
# # Set initial parameters

# %%
theta0 = np.zeros(P + 1)
cutpoint0 = -1.2

# %% [markdown]
# # Scipy implementation

# %%
def pred_value(x, theta):
    return sigmoid(x @ theta)

# %%
def loss(params, x, t):
    
    theta = params[:-1]
    cutpoint_logit = params[-1]

    cutpoint = sigmoid(cutpoint_logit)
    t_disc = sigmoid(t, cutpoint, 1e-3)
    
    x1 = np.concatenate([x, np.ones((len(x), 1))], axis=1)
    p_hat = pred_value(x1, np.array(theta))
    
    n = len(t)
    likelihood = (-1/n) * np.sum( t_disc * np.log(p_hat) + (1-t_disc)*np.log(1-p_hat) )
    
    # start with an informative beta prior on cut point
    prior = -1 * scipy.stats.beta.logpdf(cutpoint, 1.5, 1.5)

#     prior = -1 * scipy.stats.beta.logpdf(cutpoint, 2, 2)

    #prior = 0.
    
    print('Likelihood = %.5e | Prior = %.5e' % (likelihood, prior))
    
    return likelihood + prior

# %%
# minimize with scipy minimize
def fit(X, t, theta, cutpoint_logit0):
#     opt_weights = minimize(
#         fun = loss,
#         x0 = (*theta, cutpoint_logit0),
#         args = (X, t),
#         method = "Nelder-Mead"
#     )
    opt_weights = minimize(
        fun = loss,
        x0 = (*theta, cutpoint_logit0),
        args = (X, t)
    )
    return opt_weights

# %%
# loss of intial guess
loss((*theta0, cutpoint0), X, t)
# Out:
# Likelihood = 6.93147e-01 | Prior = -7.14292e-02
# 0.6217179920675406

# %%
params = fit(X, t, theta0, cutpoint0)
# Out:
# Likelihood = 6.93147e-01 | Prior = -7.14292e-02
# Likelihood = 6.93147e-01 | Prior = -7.14292e-02
# Likelihood = 6.93147e-01 | Prior = -7.14292e-02
# Likelihood = 6.93147e-01 | Prior = -7.14292e-02
# Likelihood = 6.93147e-01 | Prior = -7.14292e-02
# Likelihood = 6.93147e-01 | Prior = -7.14292e-02
# Likelihood = 6.93147e-01 | Prior = -7.14292e-02
# Likelihood = 6.93147e-01 | Prior = -7.14292e-02
# Likelihood = 6.25116e-01 | Prior = -1.36817e-01
# Likelihood = 6.25116e-01 | Prior = -1.36817e-01
# Likelihood = 6.25116e-01 | Prior = -1.36817e-01
# Likelihood = 6.25116e-01 | Prior = -1.36817e-01
# Likelihood = 6.25116e-01 | Prior = -1.36817e-01
# Likelihood = 6.25116e-01 | Prior = -1.36817e-01
# Likelihood = 6.25116e-01 | Prior = -1.36817e-01
# Likelihood = 6.25116e-01 | Prior = -1.36817e-01
# Likelihood = 6.95210e-01 | Prior = -2.20777e-01
# Likelihood = 6.95210e-01 | Prior = -2.20777e-01
# Likelihood = 6.95210e-01 | Prior = -2.20777e-01
# Likelihood = 6.95210e-01 | Prior = -2.20777e-01
# Likelihood = 6.95210e-01 | Prior = -2.20777e-01
# Likelihood = 6.95210e-01 | Prior = -2.20777e-01
# Likelihood = 6.95210e-01 | Prior = -2.20777e-01
# Likelihood = 6.95210e-01 | Prior = -2.20777e-01
# Likelihood = 6.67188e-01 | Prior = -2.19789e-01
# Likelihood = 6.67188e-01 | Prior = -2.19789e-01
# Likelihood = 6.67188e-01 | Prior = -2.19789e-01
# Likelihood = 6.67188e-01 | Prior = -2.19789e-01
# Likelihood = 6.67188e-01 | Prior = -2.19789e-01
# Likelihood = 6.67188e-01 | Prior = -2.19789e-01
# Likelihood = 6.67188e-01 | Prior = -2.19789e-01
# Likelihood = 6.67188e-01 | Prior = -2.19789e-01
# Likelihood = 5.72229e-01 | Prior = -2.15614e-01
# Likelihood = 5.72229e-01 | Prior = -2.15614e-01
# Likelihood = 5.72229e-01 | Prior = -2.15614e-01
# Likelihood = 5.72229e-01 | Prior = -2.15614e-01
# Likelihood = 5.72229e-01 | Prior = -2.15614e-01
# Likelihood = 5.72229e-01 | Prior = -2.15614e-01
# Likelihood = 5.72229e-01 | Prior = -2.15614e-01
# Likelihood = 5.72229e-01 | Prior = -2.15614e-01
# Likelihood = 3.40014e-01 | Prior = -2.34410e-01
# Likelihood = 3.40014e-01 | Prior = -2.34410e-01
# Likelihood = 3.40014e-01 | Prior = -2.34410e-01
# Likelihood = 3.40014e-01 | Prior = -2.34410e-01
# Likelihood = 3.40014e-01 | Prior = -2.34410e-01
# Likelihood = 3.40014e-01 | Prior = -2.34410e-01
# Likelihood = 3.40014e-01 | Prior = -2.34410e-01
# Likelihood = 3.40014e-01 | Prior = -2.34410e-01
# Likelihood = 2.18821e-02 | Prior = -1.92318e-01
# Likelihood = 2.18821e-02 | Prior = -1.92318e-01
# Likelihood = 2.18821e-02 | Prior = -1.92318e-01
# Likelihood = 2.18821e-02 | Prior = -1.92318e-01
# Likelihood = 2.18821e-02 | Prior = -1.92318e-01
# Likelihood = 2.18821e-02 | Prior = -1.92318e-01
# Likelihood = 2.18821e-02 | Prior = -1.92318e-01
# Likelihood = 2.18821e-02 | Prior = -1.92318e-01
# Likelihood = 2.51302e-02 | Prior = -2.13512e-01
# Likelihood = 2.51302e-02 | Prior = -2.13512e-01
# Likelihood = 2.51302e-02 | Prior = -2.13512e-01
# Likelihood = 2.51302e-02 | Prior = -2.13512e-01
# Likelihood = 2.51302e-02 | Prior = -2.13512e-01
# Likelihood = 2.51302e-02 | Prior = -2.13512e-01
# Likelihood = 2.51302e-02 | Prior = -2.13512e-01
# Likelihood = 2.51302e-02 | Prior = -2.13512e-01
# Likelihood = 2.80332e-02 | Prior = -2.38851e-01
# Likelihood = 2.80332e-02 | Prior = -2.38851e-01
# Likelihood = 2.80332e-02 | Prior = -2.38851e-01
# Likelihood = 2.80332e-02 | Prior = -2.38851e-01
# Likelihood = 2.80332e-02 | Prior = -2.38851e-01
# Likelihood = 2.80332e-02 | Prior = -2.38851e-01
# Likelihood = 2.80332e-02 | Prior = -2.38851e-01
# Likelihood = 2.80332e-02 | Prior = -2.38851e-01
# Likelihood = 2.33195e-02 | Prior = -2.41322e-01
# Likelihood = 2.33195e-02 | Prior = -2.41322e-01
# Likelihood = 2.33195e-02 | Prior = -2.41322e-01
# Likelihood = 2.33195e-02 | Prior = -2.41322e-01
# Likelihood = 2.33195e-02 | Prior = -2.41322e-01
# Likelihood = 2.33195e-02 | Prior = -2.41322e-01
# Likelihood = 2.33195e-02 | Prior = -2.41322e-01
# Likelihood = 2.33195e-02 | Prior = -2.41322e-01
# Likelihood = 1.65346e-02 | Prior = -2.41545e-01
# Likelihood = 1.65346e-02 | Prior = -2.41545e-01
# Likelihood = 1.65346e-02 | Prior = -2.41545e-01
# Likelihood = 1.65346e-02 | Prior = -2.41545e-01
# Likelihood = 1.65346e-02 | Prior = -2.41545e-01
# Likelihood = 1.65346e-02 | Prior = -2.41545e-01
# Likelihood = 1.65346e-02 | Prior = -2.41545e-01
# Likelihood = 1.65346e-02 | Prior = -2.41545e-01
# Likelihood = 7.42022e-03 | Prior = -2.41390e-01
# Likelihood = 7.42022e-03 | Prior = -2.41390e-01
# Likelihood = 7.42022e-03 | Prior = -2.41390e-01
# Likelihood = 7.42022e-03 | Prior = -2.41390e-01
# Likelihood = 7.42022e-03 | Prior = -2.41390e-01
# Likelihood = 7.42022e-03 | Prior = -2.41390e-01
# Likelihood = 7.42022e-03 | Prior = -2.41390e-01
# Likelihood = 7.42022e-03 | Prior = -2.41390e-01
# Likelihood = 3.91914e-03 | Prior = -2.41195e-01
# Likelihood = 3.91914e-03 | Prior = -2.41195e-01
# Likelihood = 3.91914e-03 | Prior = -2.41195e-01
# Likelihood = 3.91914e-03 | Prior = -2.41195e-01
# <ipython-input-2-7899cc5202f7>:3: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + (np.exp(-1 * (x - a) / b)))
# Likelihood = 3.91914e-03 | Prior = -2.41195e-01
# Likelihood = 3.91914e-03 | Prior = -2.41195e-01
# Likelihood = 3.91914e-03 | Prior = -2.41195e-01
# Likelihood = 3.91914e-03 | Prior = -2.41195e-01
# Likelihood = 2.14168e-03 | Prior = -2.41167e-01
# Likelihood = 2.14168e-03 | Prior = -2.41167e-01
# Likelihood = 2.14168e-03 | Prior = -2.41167e-01
# Likelihood = 2.14168e-03 | Prior = -2.41167e-01
# Likelihood = 2.14168e-03 | Prior = -2.41167e-01
# Likelihood = 2.14168e-03 | Prior = -2.41167e-01
# Likelihood = 2.14168e-03 | Prior = -2.41167e-01
# Likelihood = 2.14168e-03 | Prior = -2.41167e-01
# Likelihood = 1.10657e-03 | Prior = -2.41203e-01
# Likelihood = 1.10657e-03 | Prior = -2.41203e-01
# Likelihood = 1.10657e-03 | Prior = -2.41203e-01
# Likelihood = 1.10657e-03 | Prior = -2.41203e-01
# Likelihood = 1.10657e-03 | Prior = -2.41203e-01
# Likelihood = 1.10657e-03 | Prior = -2.41203e-01
# Likelihood = 1.10657e-03 | Prior = -2.41203e-01
# Likelihood = 1.10657e-03 | Prior = -2.41203e-01
# Likelihood = 5.85864e-04 | Prior = -2.41288e-01
# Likelihood = 5.85864e-04 | Prior = -2.41288e-01
# Likelihood = 5.85864e-04 | Prior = -2.41288e-01
# Likelihood = 5.85864e-04 | Prior = -2.41288e-01
# Likelihood = 5.85864e-04 | Prior = -2.41288e-01
# Likelihood = 5.85864e-04 | Prior = -2.41288e-01
# Likelihood = 5.85864e-04 | Prior = -2.41288e-01
# Likelihood = 5.85864e-04 | Prior = -2.41288e-01
# Likelihood = 4.16504e-04 | Prior = -2.41363e-01
# Likelihood = 4.16504e-04 | Prior = -2.41363e-01
# Likelihood = 4.16504e-04 | Prior = -2.41363e-01
# Likelihood = 4.16504e-04 | Prior = -2.41363e-01
# Likelihood = 4.16504e-04 | Prior = -2.41363e-01
# Likelihood = 4.16504e-04 | Prior = -2.41363e-01
# Likelihood = 4.16504e-04 | Prior = -2.41363e-01
# Likelihood = 4.16504e-04 | Prior = -2.41363e-01
# Likelihood = 2.45886e-04 | Prior = -2.41328e-01
# Likelihood = 2.45886e-04 | Prior = -2.41328e-01
# Likelihood = 2.45886e-04 | Prior = -2.41328e-01
# Likelihood = 2.45886e-04 | Prior = -2.41328e-01
# Likelihood = 2.45886e-04 | Prior = -2.41328e-01
# Likelihood = 2.45886e-04 | Prior = -2.41328e-01
# Likelihood = 2.45886e-04 | Prior = -2.41328e-01
# Likelihood = 2.45886e-04 | Prior = -2.41328e-01
# Likelihood = 1.41536e-04 | Prior = -2.41316e-01
# Likelihood = 1.41536e-04 | Prior = -2.41316e-01
# Likelihood = 1.41536e-04 | Prior = -2.41316e-01
# Likelihood = 1.41536e-04 | Prior = -2.41316e-01
# Likelihood = 1.41536e-04 | Prior = -2.41316e-01
# Likelihood = 1.41536e-04 | Prior = -2.41316e-01
# Likelihood = 1.41536e-04 | Prior = -2.41316e-01
# Likelihood = 1.41536e-04 | Prior = -2.41316e-01
# Likelihood = 9.62897e-05 | Prior = -2.41309e-01
# Likelihood = 9.62897e-05 | Prior = -2.41309e-01
# Likelihood = 9.62897e-05 | Prior = -2.41309e-01
# Likelihood = 9.62897e-05 | Prior = -2.41309e-01
# Likelihood = 9.62897e-05 | Prior = -2.41309e-01
# Likelihood = 9.62897e-05 | Prior = -2.41309e-01
# Likelihood = 9.62897e-05 | Prior = -2.41309e-01
# Likelihood = 9.62895e-05 | Prior = -2.41309e-01
# Likelihood = 7.24093e-05 | Prior = -2.41305e-01
# Likelihood = 7.24093e-05 | Prior = -2.41305e-01
# Likelihood = 7.24093e-05 | Prior = -2.41305e-01
# Likelihood = 7.24093e-05 | Prior = -2.41305e-01
# Likelihood = 7.24093e-05 | Prior = -2.41305e-01
# Likelihood = 7.24093e-05 | Prior = -2.41305e-01
# Likelihood = 7.24093e-05 | Prior = -2.41305e-01
# Likelihood = 7.24091e-05 | Prior = -2.41305e-01
# Likelihood = 6.16590e-05 | Prior = -2.41303e-01
# Likelihood = 6.16590e-05 | Prior = -2.41303e-01
# Likelihood = 6.16590e-05 | Prior = -2.41303e-01
# Likelihood = 6.16590e-05 | Prior = -2.41303e-01
# Likelihood = 6.16590e-05 | Prior = -2.41303e-01
# Likelihood = 6.16590e-05 | Prior = -2.41303e-01
# Likelihood = 6.16590e-05 | Prior = -2.41303e-01
# Likelihood = 6.16588e-05 | Prior = -2.41303e-01
# Likelihood = 5.67252e-05 | Prior = -2.41302e-01
# Likelihood = 5.67252e-05 | Prior = -2.41302e-01
# Likelihood = 5.67252e-05 | Prior = -2.41302e-01
# Likelihood = 5.67252e-05 | Prior = -2.41302e-01
# Likelihood = 5.67252e-05 | Prior = -2.41302e-01
# Likelihood = 5.67252e-05 | Prior = -2.41302e-01
# Likelihood = 5.67252e-05 | Prior = -2.41302e-01
# Likelihood = 5.67250e-05 | Prior = -2.41302e-01
# Likelihood = 5.41779e-05 | Prior = -2.41301e-01
# Likelihood = 5.41779e-05 | Prior = -2.41301e-01
# Likelihood = 5.41779e-05 | Prior = -2.41301e-01
# Likelihood = 5.41779e-05 | Prior = -2.41301e-01
# Likelihood = 5.41779e-05 | Prior = -2.41301e-01
# Likelihood = 5.41779e-05 | Prior = -2.41301e-01
# Likelihood = 5.41779e-05 | Prior = -2.41301e-01
# Likelihood = 5.41778e-05 | Prior = -2.41301e-01
# Likelihood = 5.27503e-05 | Prior = -2.41300e-01
# Likelihood = 5.27503e-05 | Prior = -2.41300e-01
# Likelihood = 5.27503e-05 | Prior = -2.41300e-01
# Likelihood = 5.27503e-05 | Prior = -2.41300e-01
# Likelihood = 5.27503e-05 | Prior = -2.41300e-01
# Likelihood = 5.27503e-05 | Prior = -2.41300e-01
# Likelihood = 5.27503e-05 | Prior = -2.41300e-01
# Likelihood = 5.27502e-05 | Prior = -2.41300e-01
# Likelihood = 5.21387e-05 | Prior = -2.41299e-01
# Likelihood = 5.21387e-05 | Prior = -2.41299e-01
# Likelihood = 5.21387e-05 | Prior = -2.41299e-01
# Likelihood = 5.21387e-05 | Prior = -2.41299e-01
# Likelihood = 5.21387e-05 | Prior = -2.41299e-01
# Likelihood = 5.21387e-05 | Prior = -2.41299e-01
# Likelihood = 5.21387e-05 | Prior = -2.41299e-01
# Likelihood = 5.21386e-05 | Prior = -2.41299e-01

# %%
print(np.stack([params.x[:-2], w]).T)
# Out:
# [[ 0.26271661 -0.43486986]
#  [-1.07775475  1.62069693]
#  [-0.06976151  0.11865208]
#  [ 0.3871457  -0.66857646]
#  [-0.23421618  0.53128924]]

# %%
sigmoid(params.x[-1])
# Out:
# 0.5115161071325429

# %%
plt.hist(t, bins=50)
plt.axvline(sigmoid(params.x[-1]))
plt.show()

# %% [markdown]
# # Pytorch implementation

# %%
import torch
import torch.optim as optim

# %%
# shifted and scaled sigmoid function
def sigmoid_torch(x, a=0, b=1.):
    return 1 / (1 + (torch.exp(-1 * (x - a) / b)))

# %%
def pred_value_torch(x, theta):
    prod = torch.matmul(x,theta)
    return sigmoid_torch(prod)

# %%
def loss_torch(params, x, t):
    
    theta = params[:-1][0]
    cutpoint_logit = params[-1]

    cutpoint = sigmoid_torch(cutpoint_logit)
    t_disc = sigmoid_torch(t, cutpoint, 1e-3)
    
    x1 = torch.cat([x, torch.ones((len(x), 1))], axis=1)
    
    p_hat = pred_value_torch(x1, theta)
    
    n = len(t)
    likelihood = (-1/n) * torch.sum( t_disc * torch.log(p_hat) + (1-t_disc)*torch.log(1-p_hat) )
    
    # start with an informative beta prior on cut point
    
    prior = -1 * scipy.stats.beta.logpdf(cutpoint.detach().numpy(), 1.5, 1.5)

    print('Likelihood = %.7e | Prior = %.7e' % (likelihood, prior))
    
    return likelihood + prior

# %%
# https://pytorch.org/tutorials/beginner/basics/autogradqs_tutorial.html
# requires requires_grad = True
theta0_torch = torch.tensor(theta0, requires_grad=True)
cutpoint0_torch = torch.tensor(cutpoint0, requires_grad=True)
X_torch = torch.tensor(X)
t_torch = torch.tensor(t)

# %%
loss_torch((theta0_torch, cutpoint0_torch), X_torch, t_torch)
# Out:
# Likelihood = 6.9314718e-01 | Prior = -7.1429192e-02
# tensor(0.6217, dtype=torch.float64, grad_fn=<AddBackward0>)

# %% [markdown]
# ### matches scipy loss!

# %%
# then optimize
# https://pytorch.org/docs/stable/optim.html
optimizer = optim.Adam([theta0_torch, cutpoint0_torch], lr=0.0001)

loss_diff = 1000
loss_curr = 1000
loss_prev = 0 

iteration_num = 1

tolerance = 1e-7

while loss_diff > tolerance:
    
    iteration_num += 1
    loss_prev = loss_curr
    
    optimizer.zero_grad()
    loss_curr = loss = loss_torch((theta0_torch, cutpoint0_torch), X_torch, t_torch)
    loss.backward()
    optimizer.step()
    
    loss_diff = torch.norm(loss_curr - loss_prev) / (1 + torch.norm(loss_curr) )

    
print(iteration_num)
# Out:
# Likelihood = 6.9314718e-01 | Prior = -7.1429192e-02
# Likelihood = 6.9309530e-01 | Prior = -7.1429192e-02
# Likelihood = 6.9304344e-01 | Prior = -7.1449120e-02
# Likelihood = 6.9299159e-01 | Prior = -7.1471340e-02
# Likelihood = 6.9293975e-01 | Prior = -7.1494749e-02
# Likelihood = 6.9288793e-01 | Prior = -7.1518920e-02
# Likelihood = 6.9283613e-01 | Prior = -7.1543809e-02
# Likelihood = 6.9278434e-01 | Prior = -7.1569233e-02
# Likelihood = 6.9273256e-01 | Prior = -7.1595195e-02
# Likelihood = 6.9268080e-01 | Prior = -7.1621602e-02
# Likelihood = 6.9262905e-01 | Prior = -7.1648502e-02
# Likelihood = 6.9257732e-01 | Prior = -7.1675802e-02
# Likelihood = 6.9252561e-01 | Prior = -7.1703593e-02
# Likelihood = 6.9247391e-01 | Prior = -7.1731740e-02
# Likelihood = 6.9242223e-01 | Prior = -7.1760310e-02
# Likelihood = 6.9237057e-01 | Prior = -7.1789236e-02
# Likelihood = 6.9231892e-01 | Prior = -7.1818562e-02
# Likelihood = 6.9226729e-01 | Prior = -7.1848222e-02
# Likelihood = 6.9221568e-01 | Prior = -7.1878259e-02
# Likelihood = 6.9216408e-01 | Prior = -7.1908628e-02
# Likelihood = 6.9211250e-01 | Prior = -7.1939330e-02
# Likelihood = 6.9206094e-01 | Prior = -7.1970365e-02
# Likelihood = 6.9200939e-01 | Prior = -7.2001664e-02
# Likelihood = 6.9195786e-01 | Prior = -7.2033318e-02
# Likelihood = 6.9190635e-01 | Prior = -7.2065236e-02
# Likelihood = 6.9185486e-01 | Prior = -7.2097464e-02
# Likelihood = 6.9180339e-01 | Prior = -7.2129957e-02
# Likelihood = 6.9175193e-01 | Prior = -7.2162736e-02
# Likelihood = 6.9170049e-01 | Prior = -7.2195689e-02
# Likelihood = 6.9164907e-01 | Prior = -7.2228974e-02
# Likelihood = 6.9159767e-01 | Prior = -7.2262478e-02
# Likelihood = 6.9154629e-01 | Prior = -7.2296223e-02
# Likelihood = 6.9149492e-01 | Prior = -7.2330165e-02
# Likelihood = 6.9144357e-01 | Prior = -7.2364326e-02
# Likelihood = 6.9139225e-01 | Prior = -7.2398706e-02
# Likelihood = 6.9134094e-01 | Prior = -7.2433259e-02
# Likelihood = 6.9128965e-01 | Prior = -7.2467964e-02
# Likelihood = 6.9123837e-01 | Prior = -7.2502909e-02
# Likelihood = 6.9118712e-01 | Prior = -7.2538028e-02
# Likelihood = 6.9113588e-01 | Prior = -7.2573254e-02
# Likelihood = 6.9108467e-01 | Prior = -7.2608630e-02
# Likelihood = 6.9103347e-01 | Prior = -7.2644203e-02
# Likelihood = 6.9098229e-01 | Prior = -7.2679881e-02
# Likelihood = 6.9093113e-01 | Prior = -7.2715688e-02
# Likelihood = 6.9087999e-01 | Prior = -7.2751623e-02
# Likelihood = 6.9082887e-01 | Prior = -7.2787664e-02
# Likelihood = 6.9077777e-01 | Prior = -7.2823789e-02
# Likelihood = 6.9072669e-01 | Prior = -7.2860087e-02
# Likelihood = 6.9067562e-01 | Prior = -7.2896401e-02
# Likelihood = 6.9062458e-01 | Prior = -7.2932888e-02
# Likelihood = 6.9057355e-01 | Prior = -7.2969369e-02
# Likelihood = 6.9052255e-01 | Prior = -7.3006001e-02
# Likelihood = 6.9047156e-01 | Prior = -7.3042626e-02
# Likelihood = 6.9042059e-01 | Prior = -7.3079379e-02
# Likelihood = 6.9036964e-01 | Prior = -7.3116171e-02
# Likelihood = 6.9031871e-01 | Prior = -7.3153001e-02
# Likelihood = 6.9026780e-01 | Prior = -7.3189870e-02
# Likelihood = 6.9021691e-01 | Prior = -7.3226822e-02
# Likelihood = 6.9016604e-01 | Prior = -7.3263768e-02
# Likelihood = 6.9011519e-01 | Prior = -7.3300797e-02
# Likelihood = 6.9006435e-01 | Prior = -7.3337798e-02
# Likelihood = 6.9001354e-01 | Prior = -7.3374882e-02
# Likelihood = 6.8996275e-01 | Prior = -7.3411914e-02
# Likelihood = 6.8991197e-01 | Prior = -7.3448941e-02
# Likelihood = 6.8986121e-01 | Prior = -7.3486073e-02
# Likelihood = 6.8981048e-01 | Prior = -7.3523154e-02
# Likelihood = 6.8975976e-01 | Prior = -7.3560229e-02
# Likelihood = 6.8970906e-01 | Prior = -7.3597342e-02
# Likelihood = 6.8965838e-01 | Prior = -7.3634427e-02
# Likelihood = 6.8960772e-01 | Prior = -7.3671528e-02
# Likelihood = 6.8955708e-01 | Prior = -7.3708578e-02
# Likelihood = 6.8950646e-01 | Prior = -7.3745711e-02
# Likelihood = 6.8945586e-01 | Prior = -7.3782727e-02
# Likelihood = 6.8940527e-01 | Prior = -7.3819781e-02
# Likelihood = 6.8935471e-01 | Prior = -7.3856784e-02
# Likelihood = 6.8930417e-01 | Prior = -7.3893781e-02
# Likelihood = 6.8925364e-01 | Prior = -7.3930749e-02
# Likelihood = 6.8920314e-01 | Prior = -7.3967667e-02
# Likelihood = 6.8915265e-01 | Prior = -7.4004579e-02
# Likelihood = 6.8910218e-01 | Prior = -7.4041485e-02
# Likelihood = 6.8905174e-01 | Prior = -7.4078317e-02
# Likelihood = 6.8900131e-01 | Prior = -7.4115166e-02
# Likelihood = 6.8895090e-01 | Prior = -7.4151920e-02
# Likelihood = 6.8890051e-01 | Prior = -7.4188690e-02
# Likelihood = 6.8885014e-01 | Prior = -7.4225365e-02
# Likelihood = 6.8879979e-01 | Prior = -7.4262012e-02
# Likelihood = 6.8874945e-01 | Prior = -7.4298631e-02
# Likelihood = 6.8869914e-01 | Prior = -7.4335199e-02
# Likelihood = 6.8864885e-01 | Prior = -7.4371739e-02
# Likelihood = 6.8859857e-01 | Prior = -7.4408250e-02
# Likelihood = 6.8854832e-01 | Prior = -7.4444667e-02
# Likelihood = 6.8849808e-01 | Prior = -7.4481056e-02
# Likelihood = 6.8844786e-01 | Prior = -7.4517460e-02
# Likelihood = 6.8839767e-01 | Prior = -7.4553726e-02
# Likelihood = 6.8834749e-01 | Prior = -7.4589964e-02
# Likelihood = 6.8829733e-01 | Prior = -7.4626173e-02
# Likelihood = 6.8824719e-01 | Prior = -7.4662333e-02
# Likelihood = 6.8819707e-01 | Prior = -7.4698420e-02
# Likelihood = 6.8814696e-01 | Prior = -7.4734434e-02
# Likelihood = 6.8809688e-01 | Prior = -7.4770443e-02
# Likelihood = 6.8804682e-01 | Prior = -7.4806357e-02
# Likelihood = 6.8799677e-01 | Prior = -7.4842221e-02
# Likelihood = 6.8794675e-01 | Prior = -7.4878035e-02
# Likelihood = 6.8789674e-01 | Prior = -7.4913754e-02
# Likelihood = 6.8784675e-01 | Prior = -7.4949424e-02
# Likelihood = 6.8779679e-01 | Prior = -7.4985065e-02
# Likelihood = 6.8774684e-01 | Prior = -7.5020613e-02
# Likelihood = 6.8769691e-01 | Prior = -7.5056154e-02
# Likelihood = 6.8764700e-01 | Prior = -7.5091557e-02
# Likelihood = 6.8759711e-01 | Prior = -7.5126888e-02
# Likelihood = 6.8754723e-01 | Prior = -7.5162214e-02
# Likelihood = 6.8749738e-01 | Prior = -7.5197401e-02
# Likelihood = 6.8744755e-01 | Prior = -7.5232538e-02
# Likelihood = 6.8739773e-01 | Prior = -7.5267625e-02
# Likelihood = 6.8734793e-01 | Prior = -7.5302619e-02
# Likelihood = 6.8729816e-01 | Prior = -7.5337518e-02
# Likelihood = 6.8724840e-01 | Prior = -7.5372324e-02
# Likelihood = 6.8719866e-01 | Prior = -7.5407124e-02
# Likelihood = 6.8714894e-01 | Prior = -7.5441786e-02
# Likelihood = 6.8709924e-01 | Prior = -7.5476420e-02
# Likelihood = 6.8704956e-01 | Prior = -7.5510917e-02
# Likelihood = 6.8699989e-01 | Prior = -7.5545298e-02
# Likelihood = 6.8695025e-01 | Prior = -7.5579607e-02
# Likelihood = 6.8690062e-01 | Prior = -7.5613888e-02
# Likelihood = 6.8685102e-01 | Prior = -7.5647988e-02
# Likelihood = 6.8680143e-01 | Prior = -7.5682083e-02
# Likelihood = 6.8675186e-01 | Prior = -7.5715996e-02
# Likelihood = 6.8670231e-01 | Prior = -7.5749881e-02
# Likelihood = 6.8665278e-01 | Prior = -7.5783607e-02
# Likelihood = 6.8660327e-01 | Prior = -7.5817195e-02
# Likelihood = 6.8655378e-01 | Prior = -7.5850735e-02
# Likelihood = 6.8650431e-01 | Prior = -7.5884136e-02
# Likelihood = 6.8645486e-01 | Prior = -7.5917445e-02
# Likelihood = 6.8640542e-01 | Prior = -7.5950594e-02
# Likelihood = 6.8635600e-01 | Prior = -7.5983672e-02
# Likelihood = 6.8630661e-01 | Prior = -7.6016613e-02
# Likelihood = 6.8625723e-01 | Prior = -7.6049417e-02
# Likelihood = 6.8620787e-01 | Prior = -7.6082128e-02
# Likelihood = 6.8615853e-01 | Prior = -7.6114658e-02
# Likelihood = 6.8610921e-01 | Prior = -7.6147095e-02
# Likelihood = 6.8605991e-01 | Prior = -7.6179395e-02
# Likelihood = 6.8601063e-01 | Prior = -7.6211558e-02
# Likelihood = 6.8596136e-01 | Prior = -7.6243540e-02
# Likelihood = 6.8591212e-01 | Prior = -7.6275430e-02
# Likelihood = 6.8586289e-01 | Prior = -7.6307161e-02
# Likelihood = 6.8581368e-01 | Prior = -7.6338734e-02
# Likelihood = 6.8576450e-01 | Prior = -7.6370170e-02
# Likelihood = 6.8571533e-01 | Prior = -7.6401447e-02
# Likelihood = 6.8566618e-01 | Prior = -7.6432522e-02
# Likelihood = 6.8561705e-01 | Prior = -7.6463461e-02
# Likelihood = 6.8556793e-01 | Prior = -7.6494264e-02
# Likelihood = 6.8551884e-01 | Prior = -7.6524886e-02
# Likelihood = 6.8546977e-01 | Prior = -7.6555351e-02
# Likelihood = 6.8542071e-01 | Prior = -7.6585635e-02
# Likelihood = 6.8537167e-01 | Prior = -7.6615827e-02
# Likelihood = 6.8532266e-01 | Prior = -7.6645751e-02
# Likelihood = 6.8527366e-01 | Prior = -7.6675518e-02
# Likelihood = 6.8522468e-01 | Prior = -7.6705149e-02
# Likelihood = 6.8517572e-01 | Prior = -7.6734600e-02
# Likelihood = 6.8512677e-01 | Prior = -7.6763827e-02
# Likelihood = 6.8507785e-01 | Prior = -7.6792919e-02
# Likelihood = 6.8502895e-01 | Prior = -7.6821787e-02
# Likelihood = 6.8498006e-01 | Prior = -7.6850499e-02
# Likelihood = 6.8493119e-01 | Prior = -7.6879030e-02
# Likelihood = 6.8488235e-01 | Prior = -7.6907339e-02
# Likelihood = 6.8483352e-01 | Prior = -7.6935490e-02
# Likelihood = 6.8478470e-01 | Prior = -7.6963397e-02
# Likelihood = 6.8473591e-01 | Prior = -7.6991168e-02
# Likelihood = 6.8468714e-01 | Prior = -7.7018694e-02
# Likelihood = 6.8463838e-01 | Prior = -7.7046064e-02
# Likelihood = 6.8458965e-01 | Prior = -7.7073254e-02
# Likelihood = 6.8454093e-01 | Prior = -7.7100201e-02
# Likelihood = 6.8449223e-01 | Prior = -7.7127012e-02
# Likelihood = 6.8444355e-01 | Prior = -7.7153579e-02
# Likelihood = 6.8439489e-01 | Prior = -7.7179901e-02
# Likelihood = 6.8434625e-01 | Prior = -7.7206089e-02
# Likelihood = 6.8429762e-01 | Prior = -7.7232033e-02
# Likelihood = 6.8424902e-01 | Prior = -7.7257821e-02
# Likelihood = 6.8420043e-01 | Prior = -7.7283386e-02
# Likelihood = 6.8415186e-01 | Prior = -7.7308707e-02
# Likelihood = 6.8410331e-01 | Prior = -7.7333872e-02
# Likelihood = 6.8405478e-01 | Prior = -7.7358816e-02
# Likelihood = 6.8400627e-01 | Prior = -7.7383603e-02
# Likelihood = 6.8395777e-01 | Prior = -7.7408124e-02
# Likelihood = 6.8390930e-01 | Prior = -7.7432490e-02
# Likelihood = 6.8386084e-01 | Prior = -7.7456568e-02
# Likelihood = 6.8381240e-01 | Prior = -7.7480513e-02
# Likelihood = 6.8376398e-01 | Prior = -7.7504214e-02
# Likelihood = 6.8371557e-01 | Prior = -7.7527759e-02
# Likelihood = 6.8366719e-01 | Prior = -7.7551039e-02
# Likelihood = 6.8361882e-01 | Prior = -7.7574142e-02
# Likelihood = 6.8357047e-01 | Prior = -7.7597002e-02
# Likelihood = 6.8352214e-01 | Prior = -7.7619684e-02
# Likelihood = 6.8347383e-01 | Prior = -7.7642145e-02
# Likelihood = 6.8342554e-01 | Prior = -7.7664473e-02
# Likelihood = 6.8337726e-01 | Prior = -7.7686536e-02
# Likelihood = 6.8332901e-01 | Prior = -7.7708378e-02
# Likelihood = 6.8328077e-01 | Prior = -7.7730022e-02
# Likelihood = 6.8323254e-01 | Prior = -7.7751488e-02
# Likelihood = 6.8318434e-01 | Prior = -7.7772734e-02
# Likelihood = 6.8313616e-01 | Prior = -7.7793759e-02
# Likelihood = 6.8308799e-01 | Prior = -7.7814563e-02
# Likelihood = 6.8303984e-01 | Prior = -7.7835213e-02
# Likelihood = 6.8299171e-01 | Prior = -7.7855620e-02
# Likelihood = 6.8294360e-01 | Prior = -7.7875829e-02
# Likelihood = 6.8289550e-01 | Prior = -7.7895839e-02
# Likelihood = 6.8284742e-01 | Prior = -7.7915629e-02
# Likelihood = 6.8279937e-01 | Prior = -7.7935220e-02
# Likelihood = 6.8275132e-01 | Prior = -7.7954636e-02
# Likelihood = 6.8270330e-01 | Prior = -7.7973787e-02
# Likelihood = 6.8265529e-01 | Prior = -7.7992806e-02
# Likelihood = 6.8260731e-01 | Prior = -7.8011583e-02
# Likelihood = 6.8255934e-01 | Prior = -7.8030118e-02
# Likelihood = 6.8251138e-01 | Prior = -7.8048477e-02
# Likelihood = 6.8246345e-01 | Prior = -7.8066638e-02
# Likelihood = 6.8241553e-01 | Prior = -7.8084601e-02
# Likelihood = 6.8236763e-01 | Prior = -7.8102322e-02
# Likelihood = 6.8231975e-01 | Prior = -7.8119868e-02
# Likelihood = 6.8227189e-01 | Prior = -7.8137215e-02
# Likelihood = 6.8222404e-01 | Prior = -7.8154365e-02
# Likelihood = 6.8217621e-01 | Prior = -7.8171230e-02
# Likelihood = 6.8212840e-01 | Prior = -7.8187963e-02
# Likelihood = 6.8208060e-01 | Prior = -7.8204454e-02
# Likelihood = 6.8203283e-01 | Prior = -7.8220748e-02
# Likelihood = 6.8198507e-01 | Prior = -7.8236801e-02
# Likelihood = 6.8193733e-01 | Prior = -7.8252657e-02
# Likelihood = 6.8188960e-01 | Prior = -7.8268336e-02
# Likelihood = 6.8184190e-01 | Prior = -7.8283775e-02
# Likelihood = 6.8179421e-01 | Prior = -7.8299017e-02
# Likelihood = 6.8174654e-01 | Prior = -7.8314039e-02
# Likelihood = 6.8169888e-01 | Prior = -7.8328820e-02
# Likelihood = 6.8165124e-01 | Prior = -7.8343448e-02
# Likelihood = 6.8160362e-01 | Prior = -7.8357835e-02
# Likelihood = 6.8155602e-01 | Prior = -7.8371982e-02
# Likelihood = 6.8150844e-01 | Prior = -7.8385910e-02
# Likelihood = 6.8146087e-01 | Prior = -7.8399618e-02
# Likelihood = 6.8141332e-01 | Prior = -7.8413152e-02
# Likelihood = 6.8136578e-01 | Prior = -7.8426445e-02
# Likelihood = 6.8131827e-01 | Prior = -7.8439519e-02
# Likelihood = 6.8127077e-01 | Prior = -7.8452353e-02
# Likelihood = 6.8122328e-01 | Prior = -7.8464990e-02
# Likelihood = 6.8117582e-01 | Prior = -7.8477408e-02
# Likelihood = 6.8112837e-01 | Prior = -7.8489543e-02
# Likelihood = 6.8108094e-01 | Prior = -7.8501524e-02
# Likelihood = 6.8103352e-01 | Prior = -7.8513243e-02
# Likelihood = 6.8098613e-01 | Prior = -7.8524701e-02
# Likelihood = 6.8093875e-01 | Prior = -7.8535961e-02
# Likelihood = 6.8089138e-01 | Prior = -7.8547004e-02
# Likelihood = 6.8084404e-01 | Prior = -7.8557784e-02
# Likelihood = 6.8079671e-01 | Prior = -7.8568368e-02
# Likelihood = 6.8074939e-01 | Prior = -7.8578625e-02
# Likelihood = 6.8070210e-01 | Prior = -7.8588750e-02
# Likelihood = 6.8065482e-01 | Prior = -7.8598592e-02
# Likelihood = 6.8060756e-01 | Prior = -7.8608172e-02
# Likelihood = 6.8056031e-01 | Prior = -7.8617535e-02
# Likelihood = 6.8051308e-01 | Prior = -7.8626635e-02
# Likelihood = 6.8046587e-01 | Prior = -7.8635518e-02
# Likelihood = 6.8041868e-01 | Prior = -7.8644160e-02
# Likelihood = 6.8037150e-01 | Prior = -7.8652476e-02
# Likelihood = 6.8032434e-01 | Prior = -7.8660617e-02
# Likelihood = 6.8027719e-01 | Prior = -7.8668432e-02
# Likelihood = 6.8023006e-01 | Prior = -7.8676050e-02
# Likelihood = 6.8018295e-01 | Prior = -7.8683407e-02
# Likelihood = 6.8013585e-01 | Prior = -7.8690524e-02
# Likelihood = 6.8008877e-01 | Prior = -7.8697380e-02
# Likelihood = 6.8004171e-01 | Prior = -7.8703909e-02
# Likelihood = 6.7999467e-01 | Prior = -7.8710264e-02
# Likelihood = 6.7994764e-01 | Prior = -7.8716292e-02
# Likelihood = 6.7990062e-01 | Prior = -7.8722059e-02
# Likelihood = 6.7985363e-01 | Prior = -7.8727586e-02
# Likelihood = 6.7980664e-01 | Prior = -7.8732830e-02
# Likelihood = 6.7975968e-01 | Prior = -7.8737770e-02
# Likelihood = 6.7971273e-01 | Prior = -7.8742448e-02
# Likelihood = 6.7966580e-01 | Prior = -7.8746887e-02
# Likelihood = 6.7961889e-01 | Prior = -7.8751000e-02
# Likelihood = 6.7957199e-01 | Prior = -7.8754894e-02
# Likelihood = 6.7952510e-01 | Prior = -7.8758485e-02
# Likelihood = 6.7947824e-01 | Prior = -7.8761748e-02
# Likelihood = 6.7943139e-01 | Prior = -7.8764772e-02
# Likelihood = 6.7938455e-01 | Prior = -7.8767492e-02
# Likelihood = 6.7933773e-01 | Prior = -7.8769907e-02
# Likelihood = 6.7929093e-01 | Prior = -7.8772018e-02
# Likelihood = 6.7924415e-01 | Prior = -7.8773889e-02
# Likelihood = 6.7919738e-01 | Prior = -7.8775433e-02
# Likelihood = 6.7915062e-01 | Prior = -7.8776695e-02
# Likelihood = 6.7910388e-01 | Prior = -7.8777609e-02
# Likelihood = 6.7905716e-01 | Prior = -7.8778283e-02
# Likelihood = 6.7901045e-01 | Prior = -7.8778631e-02
# Likelihood = 6.7896376e-01 | Prior = -7.8778675e-02
# Likelihood = 6.7891709e-01 | Prior = -7.8778392e-02
# Likelihood = 6.7887043e-01 | Prior = -7.8777848e-02
# Likelihood = 6.7882379e-01 | Prior = -7.8777000e-02
# Likelihood = 6.7877716e-01 | Prior = -7.8775760e-02
# Likelihood = 6.7873055e-01 | Prior = -7.8774280e-02
# Likelihood = 6.7868395e-01 | Prior = -7.8772453e-02
# Likelihood = 6.7863737e-01 | Prior = -7.8770299e-02
# Likelihood = 6.7859081e-01 | Prior = -7.8767862e-02
# Likelihood = 6.7854426e-01 | Prior = -7.8765099e-02
# Likelihood = 6.7849772e-01 | Prior = -7.8762009e-02
# Likelihood = 6.7845121e-01 | Prior = -7.8758593e-02
# Likelihood = 6.7840470e-01 | Prior = -7.8754851e-02
# Likelihood = 6.7835822e-01 | Prior = -7.8750760e-02
# Likelihood = 6.7831175e-01 | Prior = -7.8746409e-02
# Likelihood = 6.7826529e-01 | Prior = -7.8741665e-02
# Likelihood = 6.7821885e-01 | Prior = -7.8736595e-02
# Likelihood = 6.7817242e-01 | Prior = -7.8731242e-02
# Likelihood = 6.7812601e-01 | Prior = -7.8725562e-02
# Likelihood = 6.7807962e-01 | Prior = -7.8719491e-02
# Likelihood = 6.7803324e-01 | Prior = -7.8713093e-02
# Likelihood = 6.7798688e-01 | Prior = -7.8706412e-02
# Likelihood = 6.7794053e-01 | Prior = -7.8699404e-02
# Likelihood = 6.7789419e-01 | Prior = -7.8692004e-02
# Likelihood = 6.7784788e-01 | Prior = -7.8684299e-02
# Likelihood = 6.7780157e-01 | Prior = -7.8676246e-02
# Likelihood = 6.7775529e-01 | Prior = -7.8667887e-02
# Likelihood = 6.7770901e-01 | Prior = -7.8659137e-02
# Likelihood = 6.7766275e-01 | Prior = -7.8650060e-02
# Likelihood = 6.7761651e-01 | Prior = -7.8640655e-02
# Likelihood = 6.7757028e-01 | Prior = -7.8630924e-02
# Likelihood = 6.7752407e-01 | Prior = -7.8620844e-02
# Likelihood = 6.7747787e-01 | Prior = -7.8610371e-02
# Likelihood = 6.7743169e-01 | Prior = -7.8599637e-02
# Likelihood = 6.7738552e-01 | Prior = -7.8588511e-02
# Likelihood = 6.7733937e-01 | Prior = -7.8577078e-02
# Likelihood = 6.7729323e-01 | Prior = -7.8565254e-02
# Likelihood = 6.7724710e-01 | Prior = -7.8553102e-02
# Likelihood = 6.7720099e-01 | Prior = -7.8540666e-02
# Likelihood = 6.7715490e-01 | Prior = -7.8527815e-02
# Likelihood = 6.7710882e-01 | Prior = -7.8514637e-02
# Likelihood = 6.7706276e-01 | Prior = -7.8501132e-02
# Likelihood = 6.7701670e-01 | Prior = -7.8487277e-02
# Likelihood = 6.7697067e-01 | Prior = -7.8473116e-02
# Likelihood = 6.7692465e-01 | Prior = -7.8458584e-02
# Likelihood = 6.7687864e-01 | Prior = -7.8443725e-02
# Likelihood = 6.7683265e-01 | Prior = -7.8428515e-02
# Likelihood = 6.7678667e-01 | Prior = -7.8412999e-02
# Likelihood = 6.7674071e-01 | Prior = -7.8397112e-02
# Likelihood = 6.7669476e-01 | Prior = -7.8380897e-02
# Likelihood = 6.7664882e-01 | Prior = -7.8364375e-02
# Likelihood = 6.7660290e-01 | Prior = -7.8347481e-02
# Likelihood = 6.7655700e-01 | Prior = -7.8330303e-02
# Likelihood = 6.7651111e-01 | Prior = -7.8312753e-02
# Likelihood = 6.7646523e-01 | Prior = -7.8294896e-02
# Likelihood = 6.7641937e-01 | Prior = -7.8276710e-02
# Likelihood = 6.7637352e-01 | Prior = -7.8258196e-02
# Likelihood = 6.7632768e-01 | Prior = -7.8239397e-02
# Likelihood = 6.7628186e-01 | Prior = -7.8220268e-02
# Likelihood = 6.7623606e-01 | Prior = -7.8200833e-02
# Likelihood = 6.7619026e-01 | Prior = -7.8181026e-02
# Likelihood = 6.7614449e-01 | Prior = -7.8160976e-02
# Likelihood = 6.7609872e-01 | Prior = -7.8140597e-02
# Likelihood = 6.7605297e-01 | Prior = -7.8119911e-02
# Likelihood = 6.7600724e-01 | Prior = -7.8098918e-02
# Likelihood = 6.7596152e-01 | Prior = -7.8077638e-02
# Likelihood = 6.7591581e-01 | Prior = -7.8056051e-02
# Likelihood = 6.7587012e-01 | Prior = -7.8034200e-02
# Likelihood = 6.7582444e-01 | Prior = -7.8012085e-02
# Likelihood = 6.7577877e-01 | Prior = -7.7989662e-02
# Likelihood = 6.7573312e-01 | Prior = -7.7966952e-02
# Likelihood = 6.7568748e-01 | Prior = -7.7944022e-02
# Likelihood = 6.7564186e-01 | Prior = -7.7920762e-02
# Likelihood = 6.7559625e-01 | Prior = -7.7897281e-02
# Likelihood = 6.7555065e-01 | Prior = -7.7873491e-02
# Likelihood = 6.7550507e-01 | Prior = -7.7849502e-02
# Likelihood = 6.7545950e-01 | Prior = -7.7825249e-02
# Likelihood = 6.7541395e-01 | Prior = -7.7800796e-02
# Likelihood = 6.7536841e-01 | Prior = -7.7776078e-02
# Likelihood = 6.7532288e-01 | Prior = -7.7751138e-02
# Likelihood = 6.7527737e-01 | Prior = -7.7725956e-02
# Likelihood = 6.7523187e-01 | Prior = -7.7700529e-02
# Likelihood = 6.7518639e-01 | Prior = -7.7674947e-02
# Likelihood = 6.7514091e-01 | Prior = -7.7649144e-02
# Likelihood = 6.7509546e-01 | Prior = -7.7623184e-02
# Likelihood = 6.7505001e-01 | Prior = -7.7597067e-02
# Likelihood = 6.7500458e-01 | Prior = -7.7570729e-02
# Likelihood = 6.7495917e-01 | Prior = -7.7544191e-02
# Likelihood = 6.7491377e-01 | Prior = -7.7517497e-02
# Likelihood = 6.7486838e-01 | Prior = -7.7490602e-02
# Likelihood = 6.7482300e-01 | Prior = -7.7463638e-02
# Likelihood = 6.7477764e-01 | Prior = -7.7436518e-02
# Likelihood = 6.7473230e-01 | Prior = -7.7409241e-02
# Likelihood = 6.7468696e-01 | Prior = -7.7381829e-02
# Likelihood = 6.7464165e-01 | Prior = -7.7354326e-02
# Likelihood = 6.7459634e-01 | Prior = -7.7326667e-02
# Likelihood = 6.7455105e-01 | Prior = -7.7298872e-02
# Likelihood = 6.7450577e-01 | Prior = -7.7271031e-02
# Likelihood = 6.7446051e-01 | Prior = -7.7243054e-02
# Likelihood = 6.7441526e-01 | Prior = -7.7215096e-02
# Likelihood = 6.7437002e-01 | Prior = -7.7186980e-02
# Likelihood = 6.7432480e-01 | Prior = -7.7158773e-02
# Likelihood = 6.7427959e-01 | Prior = -7.7130541e-02
# Likelihood = 6.7423440e-01 | Prior = -7.7102261e-02
# Likelihood = 6.7418922e-01 | Prior = -7.7073956e-02
# Likelihood = 6.7414405e-01 | Prior = -7.7045559e-02
# Likelihood = 6.7409890e-01 | Prior = -7.7017181e-02
# Likelihood = 6.7405376e-01 | Prior = -7.6988711e-02
# Likelihood = 6.7400863e-01 | Prior = -7.6960259e-02
# Likelihood = 6.7396352e-01 | Prior = -7.6931782e-02
# Likelihood = 6.7391843e-01 | Prior = -7.6903323e-02
# Likelihood = 6.7387334e-01 | Prior = -7.6874839e-02
# Likelihood = 6.7382827e-01 | Prior = -7.6846328e-02
# Likelihood = 6.7378322e-01 | Prior = -7.6817924e-02
# Likelihood = 6.7373818e-01 | Prior = -7.6789428e-02
# Likelihood = 6.7369315e-01 | Prior = -7.6760995e-02
# Likelihood = 6.7364814e-01 | Prior = -7.6732623e-02
# Likelihood = 6.7360314e-01 | Prior = -7.6704248e-02
# Likelihood = 6.7355815e-01 | Prior = -7.6675913e-02
# Likelihood = 6.7351318e-01 | Prior = -7.6647619e-02
# Likelihood = 6.7346822e-01 | Prior = -7.6619408e-02
# Likelihood = 6.7342328e-01 | Prior = -7.6591151e-02
# Likelihood = 6.7337835e-01 | Prior = -7.6562999e-02
# Likelihood = 6.7333343e-01 | Prior = -7.6534910e-02
# Likelihood = 6.7328853e-01 | Prior = -7.6506839e-02
# Likelihood = 6.7324364e-01 | Prior = -7.6478830e-02
# Likelihood = 6.7319877e-01 | Prior = -7.6450928e-02
# Likelihood = 6.7315391e-01 | Prior = -7.6423110e-02
# Likelihood = 6.7310906e-01 | Prior = -7.6395311e-02
# Likelihood = 6.7306423e-01 | Prior = -7.6367574e-02
# Likelihood = 6.7301941e-01 | Prior = -7.6339900e-02
# Likelihood = 6.7297460e-01 | Prior = -7.6312354e-02
# Likelihood = 6.7292981e-01 | Prior = -7.6284849e-02
# Likelihood = 6.7288504e-01 | Prior = -7.6257428e-02
# Likelihood = 6.7284027e-01 | Prior = -7.6230070e-02
# Likelihood = 6.7279553e-01 | Prior = -7.6202797e-02
# Likelihood = 6.7275079e-01 | Prior = -7.6175652e-02
# Likelihood = 6.7270607e-01 | Prior = -7.6148526e-02
# Likelihood = 6.7266136e-01 | Prior = -7.6121485e-02
# Likelihood = 6.7261667e-01 | Prior = -7.6094572e-02
# Likelihood = 6.7257199e-01 | Prior = -7.6067723e-02
# Likelihood = 6.7252733e-01 | Prior = -7.6040958e-02
# Likelihood = 6.7248268e-01 | Prior = -7.6014278e-02
# Likelihood = 6.7243804e-01 | Prior = -7.5987683e-02
# Likelihood = 6.7239342e-01 | Prior = -7.5961151e-02
# Likelihood = 6.7234881e-01 | Prior = -7.5934703e-02
# Likelihood = 6.7230421e-01 | Prior = -7.5908407e-02
# Likelihood = 6.7225963e-01 | Prior = -7.5882108e-02
# Likelihood = 6.7221507e-01 | Prior = -7.5855938e-02
# Likelihood = 6.7217051e-01 | Prior = -7.5829831e-02
# Likelihood = 6.7212597e-01 | Prior = -7.5803853e-02
# Likelihood = 6.7208145e-01 | Prior = -7.5777917e-02
# Likelihood = 6.7203694e-01 | Prior = -7.5752065e-02
# Likelihood = 6.7199244e-01 | Prior = -7.5726321e-02
# Likelihood = 6.7194796e-01 | Prior = -7.5700684e-02
# Likelihood = 6.7190349e-01 | Prior = -7.5675088e-02
# Likelihood = 6.7185903e-01 | Prior = -7.5649621e-02
# Likelihood = 6.7181459e-01 | Prior = -7.5624196e-02
# Likelihood = 6.7177016e-01 | Prior = -7.5598878e-02
# Likelihood = 6.7172575e-01 | Prior = -7.5573646e-02
# Likelihood = 6.7168135e-01 | Prior = -7.5548477e-02
# Likelihood = 6.7163696e-01 | Prior = -7.5523416e-02
# Likelihood = 6.7159259e-01 | Prior = -7.5498440e-02
# Likelihood = 6.7154824e-01 | Prior = -7.5473549e-02
# Likelihood = 6.7150389e-01 | Prior = -7.5448788e-02
# Likelihood = 6.7145956e-01 | Prior = -7.5424113e-02
# Likelihood = 6.7141525e-01 | Prior = -7.5399524e-02
# Likelihood = 6.7137094e-01 | Prior = -7.5375042e-02
# Likelihood = 6.7132666e-01 | Prior = -7.5350623e-02
# Likelihood = 6.7128238e-01 | Prior = -7.5326291e-02
# Likelihood = 6.7123812e-01 | Prior = -7.5302110e-02
# Likelihood = 6.7119388e-01 | Prior = -7.5277927e-02
# Likelihood = 6.7114964e-01 | Prior = -7.5253896e-02
# Likelihood = 6.7110543e-01 | Prior = -7.5230039e-02
# Likelihood = 6.7106122e-01 | Prior = -7.5206202e-02
# Likelihood = 6.7101703e-01 | Prior = -7.5182517e-02
# Likelihood = 6.7097285e-01 | Prior = -7.5158896e-02
# Likelihood = 6.7092869e-01 | Prior = -7.5135449e-02
# Likelihood = 6.7088454e-01 | Prior = -7.5112088e-02
# Likelihood = 6.7084041e-01 | Prior = -7.5088836e-02
# Likelihood = 6.7079629e-01 | Prior = -7.5065669e-02
# Likelihood = 6.7075218e-01 | Prior = -7.5042700e-02
# Likelihood = 6.7070809e-01 | Prior = -7.5019816e-02
# Likelihood = 6.7066401e-01 | Prior = -7.4997063e-02
# Likelihood = 6.7061995e-01 | Prior = -7.4974440e-02
# Likelihood = 6.7057590e-01 | Prior = -7.4951948e-02
# Likelihood = 6.7053186e-01 | Prior = -7.4929586e-02
# Likelihood = 6.7048784e-01 | Prior = -7.4907399e-02
# Likelihood = 6.7044383e-01 | Prior = -7.4885277e-02
# Likelihood = 6.7039983e-01 | Prior = -7.4863351e-02
# Likelihood = 6.7035585e-01 | Prior = -7.4841601e-02
# Likelihood = 6.7031189e-01 | Prior = -7.4819937e-02
# Likelihood = 6.7026793e-01 | Prior = -7.4798492e-02
# Likelihood = 6.7022400e-01 | Prior = -7.4777201e-02
# Likelihood = 6.7018007e-01 | Prior = -7.4756040e-02
# Likelihood = 6.7013616e-01 | Prior = -7.4735099e-02
# Likelihood = 6.7009226e-01 | Prior = -7.4714311e-02
# Likelihood = 6.7004838e-01 | Prior = -7.4693654e-02
# Likelihood = 6.7000451e-01 | Prior = -7.4673217e-02
# Likelihood = 6.6996066e-01 | Prior = -7.4652933e-02
# Likelihood = 6.6991682e-01 | Prior = -7.4632825e-02
# Likelihood = 6.6987299e-01 | Prior = -7.4612936e-02
# Likelihood = 6.6982918e-01 | Prior = -7.4593179e-02
# Likelihood = 6.6978538e-01 | Prior = -7.4573664e-02
# Likelihood = 6.6974159e-01 | Prior = -7.4554303e-02
# Likelihood = 6.6969782e-01 | Prior = -7.4535184e-02
# Likelihood = 6.6965407e-01 | Prior = -7.4516263e-02
# Likelihood = 6.6961032e-01 | Prior = -7.4497517e-02
# Likelihood = 6.6956660e-01 | Prior = -7.4478970e-02
# Likelihood = 6.6952288e-01 | Prior = -7.4460665e-02
# Likelihood = 6.6947918e-01 | Prior = -7.4442537e-02
# Likelihood = 6.6943549e-01 | Prior = -7.4424651e-02
# Likelihood = 6.6939182e-01 | Prior = -7.4406963e-02
# Likelihood = 6.6934816e-01 | Prior = -7.4389562e-02
# Likelihood = 6.6930452e-01 | Prior = -7.4372293e-02
# Likelihood = 6.6926089e-01 | Prior = -7.4355268e-02
# Likelihood = 6.6921727e-01 | Prior = -7.4338462e-02
# Likelihood = 6.6917367e-01 | Prior = -7.4321900e-02
# Likelihood = 6.6913008e-01 | Prior = -7.4305558e-02
# Likelihood = 6.6908650e-01 | Prior = -7.4289416e-02
# Likelihood = 6.6904294e-01 | Prior = -7.4273516e-02
# Likelihood = 6.6899939e-01 | Prior = -7.4257881e-02
# Likelihood = 6.6895586e-01 | Prior = -7.4242401e-02
# Likelihood = 6.6891234e-01 | Prior = -7.4227187e-02
# Likelihood = 6.6886884e-01 | Prior = -7.4212171e-02
# Likelihood = 6.6882534e-01 | Prior = -7.4197421e-02
# Likelihood = 6.6878187e-01 | Prior = -7.4182870e-02
# Likelihood = 6.6873840e-01 | Prior = -7.4168606e-02
# Likelihood = 6.6869495e-01 | Prior = -7.4154520e-02
# Likelihood = 6.6865152e-01 | Prior = -7.4140610e-02
# Likelihood = 6.6860809e-01 | Prior = -7.4126989e-02
# Likelihood = 6.6856469e-01 | Prior = -7.4113611e-02
# Likelihood = 6.6852129e-01 | Prior = -7.4100387e-02
# Likelihood = 6.6847791e-01 | Prior = -7.4087408e-02
# Likelihood = 6.6843454e-01 | Prior = -7.4074694e-02
# Likelihood = 6.6839119e-01 | Prior = -7.4062113e-02
# Likelihood = 6.6834785e-01 | Prior = -7.4049776e-02
# Likelihood = 6.6830453e-01 | Prior = -7.4037661e-02
# Likelihood = 6.6826122e-01 | Prior = -7.4025700e-02
# Likelihood = 6.6821792e-01 | Prior = -7.4014006e-02
# Likelihood = 6.6817463e-01 | Prior = -7.4002489e-02
# Likelihood = 6.6813136e-01 | Prior = -7.3991194e-02
# Likelihood = 6.6808811e-01 | Prior = -7.3980120e-02
# Likelihood = 6.6804486e-01 | Prior = -7.3969224e-02
# Likelihood = 6.6800163e-01 | Prior = -7.3958460e-02
# Likelihood = 6.6795842e-01 | Prior = -7.3947941e-02
# Likelihood = 6.6791522e-01 | Prior = -7.3937600e-02
# Likelihood = 6.6787203e-01 | Prior = -7.3927480e-02
# Likelihood = 6.6782886e-01 | Prior = -7.3917537e-02
# Likelihood = 6.6778569e-01 | Prior = -7.3907706e-02
# Likelihood = 6.6774255e-01 | Prior = -7.3898118e-02
# Likelihood = 6.6769941e-01 | Prior = -7.3888664e-02
# Likelihood = 6.6765629e-01 | Prior = -7.3879387e-02
# Likelihood = 6.6761319e-01 | Prior = -7.3870288e-02
# Likelihood = 6.6757010e-01 | Prior = -7.3861367e-02
# Likelihood = 6.6752702e-01 | Prior = -7.3852579e-02
# Likelihood = 6.6748395e-01 | Prior = -7.3843946e-02
# Likelihood = 6.6744090e-01 | Prior = -7.3835446e-02
# Likelihood = 6.6739786e-01 | Prior = -7.3827124e-02
# Likelihood = 6.6735484e-01 | Prior = -7.3818957e-02
# Likelihood = 6.6731183e-01 | Prior = -7.3810879e-02
# Likelihood = 6.6726883e-01 | Prior = -7.3802957e-02
# Likelihood = 6.6722585e-01 | Prior = -7.3795212e-02
# Likelihood = 6.6718288e-01 | Prior = -7.3787556e-02
# Likelihood = 6.6713992e-01 | Prior = -7.3780056e-02
# Likelihood = 6.6709698e-01 | Prior = -7.3772667e-02
# Likelihood = 6.6705405e-01 | Prior = -7.3765433e-02
# Likelihood = 6.6701113e-01 | Prior = -7.3758266e-02
# Likelihood = 6.6696823e-01 | Prior = -7.3751276e-02
# Likelihood = 6.6692534e-01 | Prior = -7.3744353e-02
# Likelihood = 6.6688247e-01 | Prior = -7.3737497e-02
# Likelihood = 6.6683961e-01 | Prior = -7.3730863e-02
# Likelihood = 6.6679676e-01 | Prior = -7.3724274e-02
# Likelihood = 6.6675392e-01 | Prior = -7.3717773e-02
# Likelihood = 6.6671110e-01 | Prior = -7.3711361e-02
# Likelihood = 6.6666829e-01 | Prior = -7.3705105e-02
# Likelihood = 6.6662550e-01 | Prior = -7.3698915e-02
# Likelihood = 6.6658272e-01 | Prior = -7.3692837e-02
# Likelihood = 6.6653995e-01 | Prior = -7.3686848e-02
# Likelihood = 6.6649720e-01 | Prior = -7.3680880e-02
# Likelihood = 6.6645446e-01 | Prior = -7.3675091e-02
# Likelihood = 6.6641173e-01 | Prior = -7.3669368e-02
# Likelihood = 6.6636901e-01 | Prior = -7.3663712e-02
# Likelihood = 6.6632631e-01 | Prior = -7.3658145e-02
# Likelihood = 6.6628363e-01 | Prior = -7.3652622e-02
# Likelihood = 6.6624095e-01 | Prior = -7.3647210e-02
# Likelihood = 6.6619829e-01 | Prior = -7.3641821e-02
# Likelihood = 6.6615564e-01 | Prior = -7.3636565e-02
# Likelihood = 6.6611301e-01 | Prior = -7.3631354e-02
# Likelihood = 6.6607039e-01 | Prior = -7.3626209e-02
# Likelihood = 6.6602778e-01 | Prior = -7.3621175e-02
# Likelihood = 6.6598519e-01 | Prior = -7.3616142e-02
# Likelihood = 6.6594261e-01 | Prior = -7.3611197e-02
# Likelihood = 6.6590004e-01 | Prior = -7.3606319e-02
# Likelihood = 6.6585749e-01 | Prior = -7.3601530e-02
# Likelihood = 6.6581495e-01 | Prior = -7.3596808e-02
# Likelihood = 6.6577242e-01 | Prior = -7.3592085e-02
# Likelihood = 6.6572990e-01 | Prior = -7.3587452e-02
# Likelihood = 6.6568740e-01 | Prior = -7.3582885e-02
# Likelihood = 6.6564492e-01 | Prior = -7.3578363e-02
# Likelihood = 6.6560244e-01 | Prior = -7.3573908e-02
# Likelihood = 6.6555998e-01 | Prior = -7.3569474e-02
# Likelihood = 6.6551753e-01 | Prior = -7.3565108e-02
# Likelihood = 6.6547510e-01 | Prior = -7.3560764e-02
# Likelihood = 6.6543268e-01 | Prior = -7.3556508e-02
# Likelihood = 6.6539027e-01 | Prior = -7.3552342e-02
# Likelihood = 6.6534787e-01 | Prior = -7.3548176e-02
# Likelihood = 6.6530549e-01 | Prior = -7.3544076e-02
# Likelihood = 6.6526312e-01 | Prior = -7.3539977e-02
# Likelihood = 6.6522077e-01 | Prior = -7.3535944e-02
# Likelihood = 6.6517842e-01 | Prior = -7.3531933e-02
# Likelihood = 6.6513609e-01 | Prior = -7.3527989e-02
# Likelihood = 6.6509378e-01 | Prior = -7.3524112e-02
# Likelihood = 6.6505147e-01 | Prior = -7.3520257e-02
# Likelihood = 6.6500919e-01 | Prior = -7.3516469e-02
# Likelihood = 6.6496691e-01 | Prior = -7.3512659e-02
# Likelihood = 6.6492464e-01 | Prior = -7.3508915e-02
# Likelihood = 6.6488239e-01 | Prior = -7.3505238e-02
# Likelihood = 6.6484016e-01 | Prior = -7.3501539e-02
# Likelihood = 6.6479793e-01 | Prior = -7.3497907e-02
# Likelihood = 6.6475572e-01 | Prior = -7.3494341e-02
# Likelihood = 6.6471352e-01 | Prior = -7.3490775e-02
# Likelihood = 6.6467134e-01 | Prior = -7.3487299e-02
# Likelihood = 6.6462917e-01 | Prior = -7.3483822e-02
# Likelihood = 6.6458701e-01 | Prior = -7.3480390e-02
# Likelihood = 6.6454486e-01 | Prior = -7.3476980e-02
# Likelihood = 6.6450273e-01 | Prior = -7.3473615e-02
# Likelihood = 6.6446061e-01 | Prior = -7.3470249e-02
# Likelihood = 6.6441850e-01 | Prior = -7.3466973e-02
# Likelihood = 6.6437641e-01 | Prior = -7.3463652e-02
# Likelihood = 6.6433433e-01 | Prior = -7.3460398e-02
# Likelihood = 6.6429226e-01 | Prior = -7.3457188e-02
# Likelihood = 6.6425020e-01 | Prior = -7.3454023e-02
# Likelihood = 6.6420816e-01 | Prior = -7.3450813e-02
# Likelihood = 6.6416613e-01 | Prior = -7.3447670e-02
# Likelihood = 6.6412412e-01 | Prior = -7.3444550e-02
# Likelihood = 6.6408212e-01 | Prior = -7.3441451e-02
# Likelihood = 6.6404013e-01 | Prior = -7.3438398e-02
# Likelihood = 6.6399815e-01 | Prior = -7.3435388e-02
# Likelihood = 6.6395618e-01 | Prior = -7.3432401e-02
# Likelihood = 6.6391423e-01 | Prior = -7.3429392e-02
# Likelihood = 6.6387230e-01 | Prior = -7.3426449e-02
# Likelihood = 6.6383037e-01 | Prior = -7.3423507e-02
# Likelihood = 6.6378846e-01 | Prior = -7.3420564e-02
# Likelihood = 6.6374656e-01 | Prior = -7.3417711e-02
# Likelihood = 6.6370467e-01 | Prior = -7.3414857e-02
# Likelihood = 6.6366280e-01 | Prior = -7.3411981e-02
# Likelihood = 6.6362094e-01 | Prior = -7.3409195e-02
# Likelihood = 6.6357909e-01 | Prior = -7.3406386e-02
# Likelihood = 6.6353726e-01 | Prior = -7.3403643e-02
# Likelihood = 6.6349543e-01 | Prior = -7.3400856e-02
# Likelihood = 6.6345362e-01 | Prior = -7.3398159e-02
# Likelihood = 6.6341183e-01 | Prior = -7.3395439e-02
# Likelihood = 6.6337004e-01 | Prior = -7.3392741e-02
# Likelihood = 6.6332827e-01 | Prior = -7.3390110e-02
# Likelihood = 6.6328652e-01 | Prior = -7.3387435e-02
# Likelihood = 6.6324477e-01 | Prior = -7.3384781e-02
# Likelihood = 6.6320304e-01 | Prior = -7.3382173e-02
# Likelihood = 6.6316132e-01 | Prior = -7.3379586e-02
# Likelihood = 6.6311961e-01 | Prior = -7.3377044e-02
# Likelihood = 6.6307792e-01 | Prior = -7.3374480e-02
# Likelihood = 6.6303624e-01 | Prior = -7.3371938e-02
# Likelihood = 6.6299457e-01 | Prior = -7.3369396e-02
# Likelihood = 6.6295292e-01 | Prior = -7.3366921e-02
# Likelihood = 6.6291127e-01 | Prior = -7.3364402e-02
# Likelihood = 6.6286964e-01 | Prior = -7.3361926e-02
# Likelihood = 6.6282803e-01 | Prior = -7.3359496e-02
# Likelihood = 6.6278642e-01 | Prior = -7.3357021e-02
# Likelihood = 6.6274483e-01 | Prior = -7.3354612e-02
# Likelihood = 6.6270325e-01 | Prior = -7.3352137e-02
# Likelihood = 6.6266169e-01 | Prior = -7.3349796e-02
# Likelihood = 6.6262013e-01 | Prior = -7.3347387e-02
# Likelihood = 6.6257859e-01 | Prior = -7.3345023e-02
# Likelihood = 6.6253706e-01 | Prior = -7.3342682e-02
# Likelihood = 6.6249555e-01 | Prior = -7.3340363e-02
# Likelihood = 6.6245405e-01 | Prior = -7.3338043e-02
# Likelihood = 6.6241256e-01 | Prior = -7.3335746e-02
# Likelihood = 6.6237108e-01 | Prior = -7.3333427e-02
# Likelihood = 6.6232961e-01 | Prior = -7.3331197e-02
# Likelihood = 6.6228816e-01 | Prior = -7.3328900e-02
# Likelihood = 6.6224672e-01 | Prior = -7.3326625e-02
# Likelihood = 6.6220530e-01 | Prior = -7.3324417e-02
# Likelihood = 6.6216388e-01 | Prior = -7.3322187e-02
# Likelihood = 6.6212248e-01 | Prior = -7.3319979e-02
# Likelihood = 6.6208109e-01 | Prior = -7.3317815e-02
# Likelihood = 6.6203972e-01 | Prior = -7.3315563e-02
# Likelihood = 6.6199835e-01 | Prior = -7.3313399e-02
# Likelihood = 6.6195700e-01 | Prior = -7.3311236e-02
# Likelihood = 6.6191566e-01 | Prior = -7.3309162e-02
# Likelihood = 6.6187434e-01 | Prior = -7.3306998e-02
# Likelihood = 6.6183303e-01 | Prior = -7.3304857e-02
# Likelihood = 6.6179172e-01 | Prior = -7.3302738e-02
# Likelihood = 6.6175044e-01 | Prior = -7.3300641e-02
# Likelihood = 6.6170916e-01 | Prior = -7.3298567e-02
# Likelihood = 6.6166790e-01 | Prior = -7.3296470e-02
# Likelihood = 6.6162665e-01 | Prior = -7.3294396e-02
# Likelihood = 6.6158541e-01 | Prior = -7.3292344e-02
# Likelihood = 6.6154419e-01 | Prior = -7.3290292e-02
# Likelihood = 6.6150297e-01 | Prior = -7.3288284e-02
# Likelihood = 6.6146177e-01 | Prior = -7.3286187e-02
# Likelihood = 6.6142059e-01 | Prior = -7.3284180e-02
# Likelihood = 6.6137941e-01 | Prior = -7.3282217e-02
# Likelihood = 6.6133825e-01 | Prior = -7.3280231e-02
# Likelihood = 6.6129710e-01 | Prior = -7.3278224e-02
# Likelihood = 6.6125596e-01 | Prior = -7.3276305e-02
# Likelihood = 6.6121484e-01 | Prior = -7.3274298e-02
# Likelihood = 6.6117372e-01 | Prior = -7.3272357e-02
# Likelihood = 6.6113262e-01 | Prior = -7.3270416e-02
# Likelihood = 6.6109154e-01 | Prior = -7.3268498e-02
# Likelihood = 6.6105046e-01 | Prior = -7.3266557e-02
# Likelihood = 6.6100940e-01 | Prior = -7.3264616e-02
# Likelihood = 6.6096835e-01 | Prior = -7.3262742e-02
# Likelihood = 6.6092731e-01 | Prior = -7.3260846e-02
# Likelihood = 6.6088629e-01 | Prior = -7.3258972e-02
# Likelihood = 6.6084527e-01 | Prior = -7.3257098e-02
# Likelihood = 6.6080427e-01 | Prior = -7.3255269e-02
# Likelihood = 6.6076328e-01 | Prior = -7.3253417e-02
# Likelihood = 6.6072231e-01 | Prior = -7.3251565e-02
# Likelihood = 6.6068135e-01 | Prior = -7.3249714e-02
# Likelihood = 6.6064039e-01 | Prior = -7.3247884e-02
# Likelihood = 6.6059946e-01 | Prior = -7.3246077e-02
# Likelihood = 6.6055853e-01 | Prior = -7.3244248e-02
# Likelihood = 6.6051762e-01 | Prior = -7.3242440e-02
# Likelihood = 6.6047672e-01 | Prior = -7.3240656e-02
# Likelihood = 6.6043583e-01 | Prior = -7.3238893e-02
# Likelihood = 6.6039495e-01 | Prior = -7.3237108e-02
# Likelihood = 6.6035409e-01 | Prior = -7.3235323e-02
# Likelihood = 6.6031323e-01 | Prior = -7.3233583e-02
# Likelihood = 6.6027239e-01 | Prior = -7.3231843e-02
# Likelihood = 6.6023157e-01 | Prior = -7.3230080e-02
# Likelihood = 6.6019075e-01 | Prior = -7.3228362e-02
# Likelihood = 6.6014995e-01 | Prior = -7.3226622e-02
# Likelihood = 6.6010916e-01 | Prior = -7.3224881e-02
# Likelihood = 6.6006838e-01 | Prior = -7.3223186e-02
# Likelihood = 6.6002762e-01 | Prior = -7.3221490e-02
# Likelihood = 6.5998686e-01 | Prior = -7.3219794e-02
# Likelihood = 6.5994612e-01 | Prior = -7.3218121e-02
# Likelihood = 6.5990539e-01 | Prior = -7.3216425e-02
# Likelihood = 6.5986468e-01 | Prior = -7.3214774e-02
# Likelihood = 6.5982397e-01 | Prior = -7.3213145e-02
# Likelihood = 6.5978328e-01 | Prior = -7.3211449e-02
# Likelihood = 6.5974260e-01 | Prior = -7.3209820e-02
# Likelihood = 6.5970193e-01 | Prior = -7.3208146e-02
# Likelihood = 6.5966128e-01 | Prior = -7.3206540e-02
# Likelihood = 6.5962063e-01 | Prior = -7.3204866e-02
# Likelihood = 6.5958000e-01 | Prior = -7.3203237e-02
# Likelihood = 6.5953939e-01 | Prior = -7.3201631e-02
# Likelihood = 6.5949878e-01 | Prior = -7.3200069e-02
# Likelihood = 6.5945818e-01 | Prior = -7.3198462e-02
# Likelihood = 6.5941760e-01 | Prior = -7.3196877e-02
# Likelihood = 6.5937703e-01 | Prior = -7.3195293e-02
# Likelihood = 6.5933648e-01 | Prior = -7.3193664e-02
# Likelihood = 6.5929593e-01 | Prior = -7.3192124e-02
# Likelihood = 6.5925540e-01 | Prior = -7.3190562e-02
# Likelihood = 6.5921488e-01 | Prior = -7.3189022e-02
# Likelihood = 6.5917437e-01 | Prior = -7.3187438e-02
# Likelihood = 6.5913387e-01 | Prior = -7.3185920e-02
# Likelihood = 6.5909339e-01 | Prior = -7.3184381e-02
# Likelihood = 6.5905291e-01 | Prior = -7.3182841e-02
# Likelihood = 6.5901245e-01 | Prior = -7.3181301e-02
# Likelihood = 6.5897201e-01 | Prior = -7.3179783e-02
# Likelihood = 6.5893157e-01 | Prior = -7.3178266e-02
# Likelihood = 6.5889115e-01 | Prior = -7.3176815e-02
# Likelihood = 6.5885073e-01 | Prior = -7.3175253e-02
# Likelihood = 6.5881033e-01 | Prior = -7.3173802e-02
# Likelihood = 6.5876995e-01 | Prior = -7.3172329e-02
# Likelihood = 6.5872957e-01 | Prior = -7.3170856e-02
# Likelihood = 6.5868921e-01 | Prior = -7.3169383e-02
# Likelihood = 6.5864886e-01 | Prior = -7.3167910e-02
# Likelihood = 6.5860852e-01 | Prior = -7.3166460e-02
# Likelihood = 6.5856819e-01 | Prior = -7.3165009e-02
# Likelihood = 6.5852788e-01 | Prior = -7.3163581e-02
# Likelihood = 6.5848757e-01 | Prior = -7.3162152e-02
# Likelihood = 6.5844728e-01 | Prior = -7.3160724e-02
# Likelihood = 6.5840700e-01 | Prior = -7.3159251e-02
# Likelihood = 6.5836674e-01 | Prior = -7.3157867e-02
# Likelihood = 6.5832648e-01 | Prior = -7.3156483e-02
# Likelihood = 6.5828624e-01 | Prior = -7.3155055e-02
# Likelihood = 6.5824601e-01 | Prior = -7.3153626e-02
# Likelihood = 6.5820579e-01 | Prior = -7.3152220e-02
# Likelihood = 6.5816558e-01 | Prior = -7.3150836e-02
# Likelihood = 6.5812539e-01 | Prior = -7.3149453e-02
# Likelihood = 6.5808521e-01 | Prior = -7.3148091e-02
# Likelihood = 6.5804503e-01 | Prior = -7.3146730e-02
# Likelihood = 6.5800488e-01 | Prior = -7.3145346e-02
# Likelihood = 6.5796473e-01 | Prior = -7.3143984e-02
# Likelihood = 6.5792459e-01 | Prior = -7.3142645e-02
# Likelihood = 6.5788447e-01 | Prior = -7.3141261e-02
# Likelihood = 6.5784436e-01 | Prior = -7.3139944e-02
# Likelihood = 6.5780426e-01 | Prior = -7.3138627e-02
# Likelihood = 6.5776417e-01 | Prior = -7.3137266e-02
# Likelihood = 6.5772410e-01 | Prior = -7.3135926e-02
# Likelihood = 6.5768404e-01 | Prior = -7.3134609e-02
# Likelihood = 6.5764399e-01 | Prior = -7.3133292e-02
# Likelihood = 6.5760395e-01 | Prior = -7.3131975e-02
# Likelihood = 6.5756392e-01 | Prior = -7.3130658e-02
# Likelihood = 6.5752390e-01 | Prior = -7.3129341e-02
# Likelihood = 6.5748390e-01 | Prior = -7.3128024e-02
# Likelihood = 6.5744391e-01 | Prior = -7.3126730e-02
# Likelihood = 6.5740393e-01 | Prior = -7.3125480e-02
# Likelihood = 6.5736396e-01 | Prior = -7.3124163e-02
# Likelihood = 6.5732401e-01 | Prior = -7.3122935e-02
# Likelihood = 6.5728406e-01 | Prior = -7.3121618e-02
# Likelihood = 6.5724413e-01 | Prior = -7.3120390e-02
# Likelihood = 6.5720421e-01 | Prior = -7.3119073e-02
# Likelihood = 6.5716430e-01 | Prior = -7.3117823e-02
# Likelihood = 6.5712441e-01 | Prior = -7.3116595e-02
# Likelihood = 6.5708452e-01 | Prior = -7.3115367e-02
# Likelihood = 6.5704465e-01 | Prior = -7.3114117e-02
# Likelihood = 6.5700479e-01 | Prior = -7.3112889e-02
# Likelihood = 6.5696494e-01 | Prior = -7.3111639e-02
# Likelihood = 6.5692510e-01 | Prior = -7.3110412e-02
# Likelihood = 6.5688528e-01 | Prior = -7.3109206e-02
# Likelihood = 6.5684546e-01 | Prior = -7.3108023e-02
# Likelihood = 6.5680566e-01 | Prior = -7.3106773e-02
# Likelihood = 6.5676587e-01 | Prior = -7.3105590e-02
# Likelihood = 6.5672609e-01 | Prior = -7.3104384e-02
# Likelihood = 6.5668633e-01 | Prior = -7.3103134e-02
# Likelihood = 6.5664657e-01 | Prior = -7.3101995e-02
# Likelihood = 6.5660683e-01 | Prior = -7.3100790e-02
# Likelihood = 6.5656710e-01 | Prior = -7.3099584e-02
# Likelihood = 6.5652738e-01 | Prior = -7.3098423e-02
# Likelihood = 6.5648767e-01 | Prior = -7.3097262e-02
# Likelihood = 6.5644797e-01 | Prior = -7.3096079e-02
# Likelihood = 6.5640829e-01 | Prior = -7.3094874e-02
# Likelihood = 6.5636862e-01 | Prior = -7.3093757e-02
# Likelihood = 6.5632896e-01 | Prior = -7.3092641e-02
# Likelihood = 6.5628931e-01 | Prior = -7.3091480e-02
# Likelihood = 6.5624967e-01 | Prior = -7.3090319e-02
# Likelihood = 6.5621005e-01 | Prior = -7.3089158e-02
# Likelihood = 6.5617043e-01 | Prior = -7.3087997e-02
# Likelihood = 6.5613083e-01 | Prior = -7.3086881e-02
# Likelihood = 6.5609124e-01 | Prior = -7.3085765e-02
# Likelihood = 6.5605166e-01 | Prior = -7.3084626e-02
# Likelihood = 6.5601210e-01 | Prior = -7.3083510e-02
# Likelihood = 6.5597254e-01 | Prior = -7.3082438e-02
# Likelihood = 6.5593300e-01 | Prior = -7.3081277e-02
# Likelihood = 6.5589347e-01 | Prior = -7.3080183e-02
# Likelihood = 6.5585394e-01 | Prior = -7.3079022e-02
# Likelihood = 6.5581444e-01 | Prior = -7.3077950e-02
# Likelihood = 6.5577494e-01 | Prior = -7.3076856e-02
# Likelihood = 6.5573545e-01 | Prior = -7.3075785e-02
# Likelihood = 6.5569598e-01 | Prior = -7.3074690e-02
# Likelihood = 6.5565652e-01 | Prior = -7.3073619e-02
# Likelihood = 6.5561707e-01 | Prior = -7.3072547e-02
# Likelihood = 6.5557763e-01 | Prior = -7.3071453e-02
# Likelihood = 6.5553820e-01 | Prior = -7.3070381e-02
# Likelihood = 6.5549879e-01 | Prior = -7.3069332e-02
# Likelihood = 6.5545939e-01 | Prior = -7.3068282e-02
# Likelihood = 6.5541999e-01 | Prior = -7.3067211e-02
# Likelihood = 6.5538061e-01 | Prior = -7.3066206e-02
# Likelihood = 6.5534124e-01 | Prior = -7.3065112e-02
# Likelihood = 6.5530189e-01 | Prior = -7.3064085e-02
# Likelihood = 6.5526254e-01 | Prior = -7.3063035e-02
# Likelihood = 6.5522321e-01 | Prior = -7.3061941e-02
# Likelihood = 6.5518389e-01 | Prior = -7.3060936e-02
# Likelihood = 6.5514457e-01 | Prior = -7.3059932e-02
# Likelihood = 6.5510528e-01 | Prior = -7.3058927e-02
# Likelihood = 6.5506599e-01 | Prior = -7.3057900e-02
# Likelihood = 6.5502671e-01 | Prior = -7.3056850e-02
# Likelihood = 6.5498745e-01 | Prior = -7.3055845e-02
# Likelihood = 6.5494819e-01 | Prior = -7.3054840e-02
# Likelihood = 6.5490895e-01 | Prior = -7.3053836e-02
# Likelihood = 6.5486972e-01 | Prior = -7.3052786e-02
# Likelihood = 6.5483050e-01 | Prior = -7.3051826e-02
# Likelihood = 6.5479130e-01 | Prior = -7.3050821e-02
# Likelihood = 6.5475210e-01 | Prior = -7.3049816e-02
# Likelihood = 6.5471292e-01 | Prior = -7.3048811e-02
# Likelihood = 6.5467375e-01 | Prior = -7.3047851e-02
# Likelihood = 6.5463458e-01 | Prior = -7.3046869e-02
# Likelihood = 6.5459544e-01 | Prior = -7.3045864e-02
# Likelihood = 6.5455630e-01 | Prior = -7.3044859e-02
# Likelihood = 6.5451717e-01 | Prior = -7.3043943e-02
# Likelihood = 6.5447806e-01 | Prior = -7.3042983e-02
# Likelihood = 6.5443895e-01 | Prior = -7.3042001e-02
# Likelihood = 6.5439986e-01 | Prior = -7.3041085e-02
# Likelihood = 6.5436078e-01 | Prior = -7.3040080e-02
# Likelihood = 6.5432171e-01 | Prior = -7.3039142e-02
# Likelihood = 6.5428265e-01 | Prior = -7.3038182e-02
# Likelihood = 6.5424361e-01 | Prior = -7.3037222e-02
# Likelihood = 6.5420457e-01 | Prior = -7.3036284e-02
# Likelihood = 6.5416555e-01 | Prior = -7.3035368e-02
# Likelihood = 6.5412654e-01 | Prior = -7.3034430e-02
# Likelihood = 6.5408754e-01 | Prior = -7.3033515e-02
# Likelihood = 6.5404855e-01 | Prior = -7.3032577e-02
# Likelihood = 6.5400957e-01 | Prior = -7.3031661e-02
# Likelihood = 6.5397061e-01 | Prior = -7.3030723e-02
# Likelihood = 6.5393165e-01 | Prior = -7.3029808e-02
# Likelihood = 6.5389271e-01 | Prior = -7.3028870e-02
# Likelihood = 6.5385378e-01 | Prior = -7.3027932e-02
# Likelihood = 6.5381486e-01 | Prior = -7.3027061e-02
# Likelihood = 6.5377595e-01 | Prior = -7.3026168e-02
# Likelihood = 6.5373705e-01 | Prior = -7.3025274e-02
# Likelihood = 6.5369816e-01 | Prior = -7.3024381e-02
# Likelihood = 6.5365929e-01 | Prior = -7.3023465e-02
# Likelihood = 6.5362042e-01 | Prior = -7.3022617e-02
# Likelihood = 6.5358157e-01 | Prior = -7.3021679e-02
# Likelihood = 6.5354273e-01 | Prior = -7.3020830e-02
# Likelihood = 6.5350390e-01 | Prior = -7.3019914e-02
# Likelihood = 6.5346508e-01 | Prior = -7.3019021e-02
# Likelihood = 6.5342628e-01 | Prior = -7.3018128e-02
# Likelihood = 6.5338748e-01 | Prior = -7.3017279e-02
# Likelihood = 6.5334870e-01 | Prior = -7.3016430e-02
# Likelihood = 6.5330992e-01 | Prior = -7.3015537e-02
# Likelihood = 6.5327116e-01 | Prior = -7.3014688e-02
# Likelihood = 6.5323241e-01 | Prior = -7.3013795e-02
# Likelihood = 6.5319367e-01 | Prior = -7.3012946e-02
# Likelihood = 6.5315495e-01 | Prior = -7.3012098e-02
# Likelihood = 6.5311623e-01 | Prior = -7.3011249e-02
# Likelihood = 6.5307753e-01 | Prior = -7.3010400e-02
# Likelihood = 6.5303883e-01 | Prior = -7.3009507e-02
# Likelihood = 6.5300015e-01 | Prior = -7.3008703e-02
# Likelihood = 6.5296148e-01 | Prior = -7.3007854e-02
# Likelihood = 6.5292282e-01 | Prior = -7.3007028e-02
# Likelihood = 6.5288417e-01 | Prior = -7.3006224e-02
# Likelihood = 6.5284553e-01 | Prior = -7.3005375e-02
# Likelihood = 6.5280691e-01 | Prior = -7.3004526e-02
# Likelihood = 6.5276829e-01 | Prior = -7.3003722e-02
# Likelihood = 6.5272969e-01 | Prior = -7.3002896e-02
# Likelihood = 6.5269110e-01 | Prior = -7.3002047e-02
# Likelihood = 6.5265252e-01 | Prior = -7.3001199e-02
# Likelihood = 6.5261395e-01 | Prior = -7.3000439e-02
# Likelihood = 6.5257539e-01 | Prior = -7.2999657e-02
# Likelihood = 6.5253684e-01 | Prior = -7.2998853e-02
# Likelihood = 6.5249830e-01 | Prior = -7.2998027e-02
# Likelihood = 6.5245978e-01 | Prior = -7.2997268e-02
# Likelihood = 6.5242127e-01 | Prior = -7.2996441e-02
# Likelihood = 6.5238276e-01 | Prior = -7.2995637e-02
# Likelihood = 6.5234427e-01 | Prior = -7.2994855e-02
# Likelihood = 6.5230579e-01 | Prior = -7.2994051e-02
# Likelihood = 6.5226732e-01 | Prior = -7.2993247e-02
# Likelihood = 6.5222887e-01 | Prior = -7.2992465e-02
# Likelihood = 6.5219042e-01 | Prior = -7.2991661e-02
# Likelihood = 6.5215198e-01 | Prior = -7.2990835e-02
# Likelihood = 6.5211356e-01 | Prior = -7.2990076e-02
# ...
# Likelihood = 5.0053773e-01 | Prior = -7.3031103e-02
# Likelihood = 5.0053224e-01 | Prior = -7.3032666e-02
# Likelihood = 5.0052676e-01 | Prior = -7.3031773e-02
# Likelihood = 5.0052127e-01 | Prior = -7.3032153e-02
# Likelihood = 5.0051578e-01 | Prior = -7.3032354e-02
# Likelihood = 5.0051030e-01 | Prior = -7.3031728e-02
# Likelihood = 5.0050482e-01 | Prior = -7.3032689e-02
# Likelihood = 5.0049933e-01 | Prior = -7.3031728e-02
# Likelihood = 5.0049385e-01 | Prior = -7.3032577e-02
# Likelihood = 5.0048837e-01 | Prior = -7.3032041e-02
# Likelihood = 5.0048289e-01 | Prior = -7.3032376e-02
# Likelihood = 5.0047742e-01 | Prior = -7.3032264e-02
# Likelihood = 5.0047194e-01 | Prior = -7.3032309e-02
# Likelihood = 5.0046646e-01 | Prior = -7.3032376e-02
# Likelihood = 5.0046099e-01 | Prior = -7.3032309e-02
# Likelihood = 5.0045551e-01 | Prior = -7.3032510e-02
# Likelihood = 5.0045004e-01 | Prior = -7.3032197e-02
# Likelihood = 5.0044457e-01 | Prior = -7.3032733e-02
# Likelihood = 5.0043910e-01 | Prior = -7.3032108e-02
# Likelihood = 5.0043363e-01 | Prior = -7.3032889e-02
# Likelihood = 5.0042816e-01 | Prior = -7.3032041e-02
# Likelihood = 5.0042269e-01 | Prior = -7.3033046e-02
# Likelihood = 5.0041723e-01 | Prior = -7.3032041e-02
# Likelihood = 5.0041176e-01 | Prior = -7.3033046e-02
# Likelihood = 5.0040630e-01 | Prior = -7.3032153e-02
# Likelihood = 5.0040083e-01 | Prior = -7.3033046e-02
# Likelihood = 5.0039537e-01 | Prior = -7.3032264e-02
# Likelihood = 5.0038991e-01 | Prior = -7.3033046e-02
# Likelihood = 5.0038445e-01 | Prior = -7.3032264e-02
# Likelihood = 5.0037899e-01 | Prior = -7.3033247e-02
# Likelihood = 5.0037353e-01 | Prior = -7.3032108e-02
# Likelihood = 5.0036807e-01 | Prior = -7.3033470e-02
# Likelihood = 5.0036262e-01 | Prior = -7.3032041e-02
# Likelihood = 5.0035716e-01 | Prior = -7.3033582e-02
# Likelihood = 5.0035171e-01 | Prior = -7.3032041e-02
# Likelihood = 5.0034626e-01 | Prior = -7.3033671e-02
# Likelihood = 5.0034080e-01 | Prior = -7.3032041e-02
# Likelihood = 5.0033535e-01 | Prior = -7.3033738e-02
# Likelihood = 5.0032990e-01 | Prior = -7.3032197e-02
# Likelihood = 5.0032446e-01 | Prior = -7.3033515e-02
# Likelihood = 5.0031901e-01 | Prior = -7.3032577e-02
# Likelihood = 5.0031356e-01 | Prior = -7.3033202e-02
# Likelihood = 5.0030812e-01 | Prior = -7.3033046e-02
# Likelihood = 5.0030267e-01 | Prior = -7.3032778e-02
# Likelihood = 5.0029723e-01 | Prior = -7.3033515e-02
# Likelihood = 5.0029178e-01 | Prior = -7.3032532e-02
# Likelihood = 5.0028634e-01 | Prior = -7.3033738e-02
# Likelihood = 5.0028090e-01 | Prior = -7.3032510e-02
# Likelihood = 5.0027546e-01 | Prior = -7.3033671e-02
# Likelihood = 5.0027003e-01 | Prior = -7.3032889e-02
# Likelihood = 5.0026459e-01 | Prior = -7.3033269e-02
# Likelihood = 5.0025915e-01 | Prior = -7.3033358e-02
# Likelihood = 5.0025372e-01 | Prior = -7.3032956e-02
# Likelihood = 5.0024828e-01 | Prior = -7.3033738e-02
# Likelihood = 5.0024285e-01 | Prior = -7.3032733e-02
# Likelihood = 5.0023742e-01 | Prior = -7.3033894e-02
# Likelihood = 5.0023199e-01 | Prior = -7.3032845e-02
# Likelihood = 5.0022656e-01 | Prior = -7.3033783e-02
# Likelihood = 5.0022113e-01 | Prior = -7.3033090e-02
# Likelihood = 5.0021570e-01 | Prior = -7.3033582e-02
# Likelihood = 5.0021027e-01 | Prior = -7.3033358e-02
# Likelihood = 5.0020485e-01 | Prior = -7.3033515e-02
# Likelihood = 5.0019942e-01 | Prior = -7.3033470e-02
# Likelihood = 5.0019400e-01 | Prior = -7.3033470e-02
# Likelihood = 5.0018858e-01 | Prior = -7.3033626e-02
# Likelihood = 5.0018315e-01 | Prior = -7.3033425e-02
# Likelihood = 5.0017773e-01 | Prior = -7.3033671e-02
# Likelihood = 5.0017231e-01 | Prior = -7.3033626e-02
# Likelihood = 5.0016690e-01 | Prior = -7.3033470e-02
# Likelihood = 5.0016148e-01 | Prior = -7.3033894e-02
# Likelihood = 5.0015606e-01 | Prior = -7.3033425e-02
# Likelihood = 5.0015065e-01 | Prior = -7.3033850e-02
# Likelihood = 5.0014523e-01 | Prior = -7.3033671e-02
# Likelihood = 5.0013982e-01 | Prior = -7.3033738e-02
# Likelihood = 5.0013441e-01 | Prior = -7.3033738e-02
# Likelihood = 5.0012900e-01 | Prior = -7.3033894e-02
# Likelihood = 5.0012358e-01 | Prior = -7.3033582e-02
# Likelihood = 5.0011818e-01 | Prior = -7.3034207e-02
# Likelihood = 5.0011277e-01 | Prior = -7.3033358e-02
# Likelihood = 5.0010736e-01 | Prior = -7.3034430e-02
# Likelihood = 5.0010195e-01 | Prior = -7.3033425e-02
# Likelihood = 5.0009655e-01 | Prior = -7.3034274e-02
# Likelihood = 5.0009115e-01 | Prior = -7.3033738e-02
# Likelihood = 5.0008574e-01 | Prior = -7.3034051e-02
# Likelihood = 5.0008034e-01 | Prior = -7.3034051e-02
# Likelihood = 5.0007494e-01 | Prior = -7.3033850e-02
# Likelihood = 5.0006954e-01 | Prior = -7.3034274e-02
# Likelihood = 5.0006414e-01 | Prior = -7.3033850e-02
# Likelihood = 5.0005874e-01 | Prior = -7.3034274e-02
# Likelihood = 5.0005335e-01 | Prior = -7.3033961e-02
# Likelihood = 5.0004795e-01 | Prior = -7.3034207e-02
# Likelihood = 5.0004256e-01 | Prior = -7.3034207e-02
# Likelihood = 5.0003716e-01 | Prior = -7.3034006e-02
# Likelihood = 5.0003177e-01 | Prior = -7.3034520e-02
# Likelihood = 5.0002638e-01 | Prior = -7.3033738e-02
# Likelihood = 5.0002099e-01 | Prior = -7.3034899e-02
# Likelihood = 5.0001560e-01 | Prior = -7.3033515e-02
# Likelihood = 5.0001021e-01 | Prior = -7.3035123e-02
# Likelihood = 5.0000482e-01 | Prior = -7.3033470e-02
# Likelihood = 4.9999944e-01 | Prior = -7.3035212e-02
# Likelihood = 4.9999405e-01 | Prior = -7.3033515e-02
# Likelihood = 4.9998867e-01 | Prior = -7.3035212e-02
# Likelihood = 4.9998329e-01 | Prior = -7.3033582e-02
# Likelihood = 4.9997790e-01 | Prior = -7.3035324e-02
# Likelihood = 4.9997252e-01 | Prior = -7.3033515e-02
# Likelihood = 4.9996714e-01 | Prior = -7.3035435e-02
# Likelihood = 4.9996176e-01 | Prior = -7.3033582e-02
# Likelihood = 4.9995639e-01 | Prior = -7.3035435e-02
# Likelihood = 4.9995101e-01 | Prior = -7.3033671e-02
# Likelihood = 4.9994563e-01 | Prior = -7.3035391e-02
# Likelihood = 4.9994026e-01 | Prior = -7.3033894e-02
# Likelihood = 4.9993488e-01 | Prior = -7.3035212e-02
# Likelihood = 4.9992951e-01 | Prior = -7.3034118e-02
# Likelihood = 4.9992414e-01 | Prior = -7.3035123e-02
# Likelihood = 4.9991877e-01 | Prior = -7.3034363e-02
# Likelihood = 4.9991340e-01 | Prior = -7.3034899e-02
# Likelihood = 4.9990803e-01 | Prior = -7.3034676e-02
# Likelihood = 4.9990266e-01 | Prior = -7.3034698e-02
# Likelihood = 4.9989730e-01 | Prior = -7.3034966e-02
# Likelihood = 4.9989193e-01 | Prior = -7.3034520e-02
# Likelihood = 4.9988657e-01 | Prior = -7.3035212e-02
# Likelihood = 4.9988120e-01 | Prior = -7.3034363e-02
# Likelihood = 4.9987584e-01 | Prior = -7.3035480e-02
# Likelihood = 4.9987048e-01 | Prior = -7.3034162e-02
# Likelihood = 4.9986512e-01 | Prior = -7.3035793e-02
# Likelihood = 4.9985976e-01 | Prior = -7.3033961e-02
# Likelihood = 4.9985440e-01 | Prior = -7.3036016e-02
# Likelihood = 4.9984904e-01 | Prior = -7.3033894e-02
# Likelihood = 4.9984369e-01 | Prior = -7.3036172e-02
# Likelihood = 4.9983833e-01 | Prior = -7.3033805e-02
# Likelihood = 4.9983298e-01 | Prior = -7.3036373e-02
# Likelihood = 4.9982763e-01 | Prior = -7.3033671e-02
# Likelihood = 4.9982227e-01 | Prior = -7.3036597e-02
# Likelihood = 4.9981692e-01 | Prior = -7.3033626e-02
# Likelihood = 4.9981157e-01 | Prior = -7.3036597e-02
# Likelihood = 4.9980622e-01 | Prior = -7.3033805e-02
# Likelihood = 4.9980088e-01 | Prior = -7.3036530e-02
# Likelihood = 4.9979553e-01 | Prior = -7.3033894e-02
# Likelihood = 4.9979018e-01 | Prior = -7.3036552e-02
# Likelihood = 4.9978484e-01 | Prior = -7.3034051e-02
# Likelihood = 4.9977950e-01 | Prior = -7.3036329e-02
# Likelihood = 4.9977415e-01 | Prior = -7.3034520e-02
# Likelihood = 4.9976881e-01 | Prior = -7.3035860e-02
# Likelihood = 4.9976347e-01 | Prior = -7.3035100e-02
# Likelihood = 4.9975813e-01 | Prior = -7.3035368e-02
# Likelihood = 4.9975279e-01 | Prior = -7.3035681e-02
# Likelihood = 4.9974745e-01 | Prior = -7.3034944e-02
# Likelihood = 4.9974212e-01 | Prior = -7.3036061e-02
# Likelihood = 4.9973678e-01 | Prior = -7.3034810e-02
# Likelihood = 4.9973145e-01 | Prior = -7.3036217e-02
# Likelihood = 4.9972611e-01 | Prior = -7.3034743e-02
# Likelihood = 4.9972078e-01 | Prior = -7.3036329e-02
# Likelihood = 4.9971545e-01 | Prior = -7.3034810e-02
# Likelihood = 4.9971012e-01 | Prior = -7.3036284e-02
# Likelihood = 4.9970479e-01 | Prior = -7.3035056e-02
# Likelihood = 4.9969946e-01 | Prior = -7.3035971e-02
# Likelihood = 4.9969414e-01 | Prior = -7.3035592e-02
# Likelihood = 4.9968881e-01 | Prior = -7.3035435e-02
# Likelihood = 4.9968348e-01 | Prior = -7.3036284e-02
# Likelihood = 4.9967816e-01 | Prior = -7.3034810e-02
# Likelihood = 4.9967284e-01 | Prior = -7.3036976e-02
# Likelihood = 4.9966752e-01 | Prior = -7.3034274e-02
# Likelihood = 4.9966219e-01 | Prior = -7.3037534e-02
# Likelihood = 4.9965687e-01 | Prior = -7.3033894e-02
# Likelihood = 4.9965156e-01 | Prior = -7.3037825e-02
# Likelihood = 4.9964624e-01 | Prior = -7.3034006e-02
# Likelihood = 4.9964092e-01 | Prior = -7.3037445e-02
# Likelihood = 4.9963561e-01 | Prior = -7.3034743e-02
# Likelihood = 4.9963029e-01 | Prior = -7.3036686e-02
# Likelihood = 4.9962498e-01 | Prior = -7.3035636e-02
# Likelihood = 4.9961966e-01 | Prior = -7.3035860e-02
# Likelihood = 4.9961435e-01 | Prior = -7.3036530e-02
# Likelihood = 4.9960904e-01 | Prior = -7.3035212e-02
# Likelihood = 4.9960373e-01 | Prior = -7.3036976e-02
# Likelihood = 4.9959842e-01 | Prior = -7.3035123e-02
# Likelihood = 4.9959312e-01 | Prior = -7.3037065e-02
# Likelihood = 4.9958781e-01 | Prior = -7.3035123e-02
# Likelihood = 4.9958250e-01 | Prior = -7.3037065e-02
# Likelihood = 4.9957720e-01 | Prior = -7.3035391e-02
# Likelihood = 4.9957190e-01 | Prior = -7.3036753e-02
# Likelihood = 4.9956659e-01 | Prior = -7.3035904e-02
# Likelihood = 4.9956129e-01 | Prior = -7.3036284e-02
# Likelihood = 4.9955599e-01 | Prior = -7.3036396e-02
# Likelihood = 4.9955069e-01 | Prior = -7.3035971e-02
# Likelihood = 4.9954539e-01 | Prior = -7.3036753e-02
# Likelihood = 4.9954010e-01 | Prior = -7.3035748e-02
# Likelihood = 4.9953480e-01 | Prior = -7.3036976e-02
# Likelihood = 4.9952951e-01 | Prior = -7.3035793e-02
# Likelihood = 4.9952421e-01 | Prior = -7.3036820e-02
# Likelihood = 4.9951892e-01 | Prior = -7.3036217e-02
# Likelihood = 4.9951363e-01 | Prior = -7.3036373e-02
# Likelihood = 4.9950833e-01 | Prior = -7.3036753e-02
# Likelihood = 4.9950304e-01 | Prior = -7.3036016e-02
# Likelihood = 4.9949776e-01 | Prior = -7.3037065e-02
# Likelihood = 4.9949247e-01 | Prior = -7.3035971e-02
# Likelihood = 4.9948718e-01 | Prior = -7.3036976e-02
# Likelihood = 4.9948189e-01 | Prior = -7.3036396e-02
# Likelihood = 4.9947661e-01 | Prior = -7.3036530e-02
# Likelihood = 4.9947133e-01 | Prior = -7.3036864e-02
# Likelihood = 4.9946604e-01 | Prior = -7.3036284e-02
# Likelihood = 4.9946076e-01 | Prior = -7.3037110e-02
# Likelihood = 4.9945548e-01 | Prior = -7.3036172e-02
# Likelihood = 4.9945020e-01 | Prior = -7.3037244e-02
# Likelihood = 4.9944492e-01 | Prior = -7.3036284e-02
# Likelihood = 4.9943964e-01 | Prior = -7.3037065e-02
# Likelihood = 4.9943437e-01 | Prior = -7.3036597e-02
# Likelihood = 4.9942909e-01 | Prior = -7.3036909e-02
# Likelihood = 4.9942382e-01 | Prior = -7.3036753e-02
# Likelihood = 4.9941854e-01 | Prior = -7.3036954e-02
# Likelihood = 4.9941327e-01 | Prior = -7.3036686e-02
# Likelihood = 4.9940800e-01 | Prior = -7.3037132e-02
# Likelihood = 4.9940273e-01 | Prior = -7.3036686e-02
# Likelihood = 4.9939746e-01 | Prior = -7.3037132e-02
# Likelihood = 4.9939219e-01 | Prior = -7.3036820e-02
# Likelihood = 4.9938692e-01 | Prior = -7.3037065e-02
# Likelihood = 4.9938166e-01 | Prior = -7.3036976e-02
# Likelihood = 4.9937639e-01 | Prior = -7.3037065e-02
# Likelihood = 4.9937113e-01 | Prior = -7.3036976e-02
# Likelihood = 4.9936586e-01 | Prior = -7.3037222e-02
# Likelihood = 4.9936060e-01 | Prior = -7.3036820e-02
# Likelihood = 4.9935534e-01 | Prior = -7.3037601e-02
# Likelihood = 4.9935008e-01 | Prior = -7.3036440e-02
# Likelihood = 4.9934482e-01 | Prior = -7.3038070e-02
# Likelihood = 4.9933956e-01 | Prior = -7.3036128e-02
# Likelihood = 4.9933431e-01 | Prior = -7.3038405e-02
# Likelihood = 4.9932905e-01 | Prior = -7.3035971e-02
# Likelihood = 4.9932379e-01 | Prior = -7.3038539e-02
# Likelihood = 4.9931854e-01 | Prior = -7.3035971e-02
# Likelihood = 4.9931329e-01 | Prior = -7.3038606e-02
# Likelihood = 4.9930804e-01 | Prior = -7.3036128e-02
# Likelihood = 4.9930278e-01 | Prior = -7.3038405e-02
# Likelihood = 4.9929753e-01 | Prior = -7.3036530e-02
# Likelihood = 4.9929229e-01 | Prior = -7.3037914e-02
# Likelihood = 4.9928704e-01 | Prior = -7.3037289e-02
# Likelihood = 4.9928179e-01 | Prior = -7.3037222e-02
# Likelihood = 4.9927654e-01 | Prior = -7.3037914e-02
# Likelihood = 4.9927130e-01 | Prior = -7.3036909e-02
# Likelihood = 4.9926606e-01 | Prior = -7.3038137e-02
# Likelihood = 4.9926081e-01 | Prior = -7.3036909e-02
# Likelihood = 4.9925557e-01 | Prior = -7.3038137e-02
# Likelihood = 4.9925033e-01 | Prior = -7.3037065e-02
# Likelihood = 4.9924509e-01 | Prior = -7.3037959e-02
# Likelihood = 4.9923985e-01 | Prior = -7.3037445e-02
# Likelihood = 4.9923461e-01 | Prior = -7.3037691e-02
# Likelihood = 4.9922938e-01 | Prior = -7.3037691e-02
# Likelihood = 4.9922414e-01 | Prior = -7.3037646e-02
# Likelihood = 4.9921891e-01 | Prior = -7.3037758e-02
# Likelihood = 4.9921367e-01 | Prior = -7.3037691e-02
# Likelihood = 4.9920844e-01 | Prior = -7.3037825e-02
# Likelihood = 4.9920321e-01 | Prior = -7.3037691e-02
# Likelihood = 4.9919798e-01 | Prior = -7.3037914e-02
# Likelihood = 4.9919275e-01 | Prior = -7.3037691e-02
# Likelihood = 4.9918752e-01 | Prior = -7.3038026e-02
# Likelihood = 4.9918229e-01 | Prior = -7.3037646e-02
# Likelihood = 4.9917707e-01 | Prior = -7.3038137e-02
# Likelihood = 4.9917184e-01 | Prior = -7.3037691e-02
# Likelihood = 4.9916662e-01 | Prior = -7.3038137e-02
# Likelihood = 4.9916139e-01 | Prior = -7.3037825e-02
# Likelihood = 4.9915617e-01 | Prior = -7.3038070e-02
# Likelihood = 4.9915095e-01 | Prior = -7.3037914e-02
# Likelihood = 4.9914573e-01 | Prior = -7.3038182e-02
# Likelihood = 4.9914051e-01 | Prior = -7.3037825e-02
# Likelihood = 4.9913529e-01 | Prior = -7.3038405e-02
# Likelihood = 4.9913008e-01 | Prior = -7.3037691e-02
# Likelihood = 4.9912486e-01 | Prior = -7.3038562e-02
# Likelihood = 4.9911964e-01 | Prior = -7.3037691e-02
# Likelihood = 4.9911443e-01 | Prior = -7.3038606e-02
# Likelihood = 4.9910922e-01 | Prior = -7.3037802e-02
# Likelihood = 4.9910401e-01 | Prior = -7.3038539e-02
# Likelihood = 4.9909879e-01 | Prior = -7.3037959e-02
# Likelihood = 4.9909358e-01 | Prior = -7.3038450e-02
# Likelihood = 4.9908838e-01 | Prior = -7.3038227e-02
# Likelihood = 4.9908317e-01 | Prior = -7.3038182e-02
# Likelihood = 4.9907796e-01 | Prior = -7.3038606e-02
# Likelihood = 4.9907275e-01 | Prior = -7.3037959e-02
# Likelihood = 4.9906755e-01 | Prior = -7.3038830e-02
# Likelihood = 4.9906235e-01 | Prior = -7.3037869e-02
# Likelihood = 4.9905714e-01 | Prior = -7.3038986e-02
# Likelihood = 4.9905194e-01 | Prior = -7.3037869e-02
# Likelihood = 4.9904674e-01 | Prior = -7.3038986e-02
# Likelihood = 4.9904154e-01 | Prior = -7.3038026e-02
# Likelihood = 4.9903634e-01 | Prior = -7.3038874e-02
# Likelihood = 4.9903114e-01 | Prior = -7.3038294e-02
# Likelihood = 4.9902595e-01 | Prior = -7.3038606e-02
# Likelihood = 4.9902075e-01 | Prior = -7.3038718e-02
# Likelihood = 4.9901556e-01 | Prior = -7.3038294e-02
# Likelihood = 4.9901036e-01 | Prior = -7.3038986e-02
# Likelihood = 4.9900517e-01 | Prior = -7.3038294e-02
# Likelihood = 4.9899998e-01 | Prior = -7.3038964e-02
# Likelihood = 4.9899479e-01 | Prior = -7.3038405e-02
# Likelihood = 4.9898960e-01 | Prior = -7.3038986e-02
# Likelihood = 4.9898441e-01 | Prior = -7.3038539e-02
# Likelihood = 4.9897922e-01 | Prior = -7.3038763e-02
# Likelihood = 4.9897404e-01 | Prior = -7.3038986e-02
# Likelihood = 4.9896885e-01 | Prior = -7.3038405e-02
# Likelihood = 4.9896367e-01 | Prior = -7.3039388e-02
# Likelihood = 4.9895848e-01 | Prior = -7.3038070e-02
# Likelihood = 4.9895330e-01 | Prior = -7.3039924e-02
# Likelihood = 4.9894812e-01 | Prior = -7.3037490e-02
# Likelihood = 4.9894294e-01 | Prior = -7.3040683e-02
# Likelihood = 4.9893776e-01 | Prior = -7.3036753e-02
# Likelihood = 4.9893258e-01 | Prior = -7.3041621e-02
# Likelihood = 4.9892740e-01 | Prior = -7.3035815e-02
# Likelihood = 4.9892223e-01 | Prior = -7.3042514e-02
# Likelihood = 4.9891705e-01 | Prior = -7.3035480e-02
# Likelihood = 4.9891188e-01 | Prior = -7.3042157e-02
# Likelihood = 4.9890670e-01 | Prior = -7.3036864e-02
# 11166

# %%
theta0_torch
# Out:
# tensor([-0.3754,  0.9967,  0.0729, -0.5598,  0.3955, -0.0292],
#        dtype=torch.float64, requires_grad=True)

# %%
cutpoint0_torch
# Out:
# tensor(-1.1940, requires_grad=True)

# %%
sigmoid_torch(cutpoint0_torch)
# Out:
# tensor(0.2325, grad_fn=<MulBackward0>)

# %%
plt.hist(t, bins=50)
plt.axvline(sigmoid_torch(cutpoint0_torch))
plt.show()

# %%
X.shape
# Out:
# (10000, 5)

# %%
torch(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-548f0bee466c> in <module>
# ----> 1 torch(0)
#
# TypeError: 'module' object is not callable

# %%
torch.zeros(3, requires_grad=True)
# Out:
# tensor([0., 0., 0.], requires_grad=True)

# %%
torch.tensor(0., requires_grad=True)
# Out:
# tensor(0., requires_grad=True)

# %%
t_torch
# Out:
# tensor([0.0583, 0.3770, 0.1022,  ..., 0.1177, 0.3040, 0.1219],
#        dtype=torch.float64)
